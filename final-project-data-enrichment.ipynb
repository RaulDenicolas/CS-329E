# %% [markdown]
# #Final Project - Option 2: Data Enrichment at scale

# %% [markdown]
# ##Setup

# %% [markdown]
# #####Create a dataset for storing the AI tables and another for storing the AI models

# %%
# %%bigquery
# CREATE SCHEMA `automated-style-411721`.retails_stg_ai
# Out:
# Executing query with job ID: 447c8fe6-c2d7-4550-ab5c-d415eedd0955
# Query executing: 0.55s
# ERROR:
#  409 Already Exists: Dataset automated-style-411721:retails_stg_ai
#
# Location: US
# Job ID: 447c8fe6-c2d7-4550-ab5c-d415eedd0955

# %%
# %%bigquery
# CREATE SCHEMA `automated-style-411721`.remote_models;
# Out:
# Executing query with job ID: b1ec8eb0-9d56-40c5-8a43-ac9c5198ff74
# Query executing: 0.42s
# ERROR:
#  409 Already Exists: Dataset automated-style-411721:remote_models
#
# Location: US
# Job ID: b1ec8eb0-9d56-40c5-8a43-ac9c5198ff74

# %% [markdown]
# #####Before running this cell, create the remote connection and assign the IAM role `Vertex AI User` to the service account associated with the connection.

# %%
# %%bigquery
# create or replace model remote_models.gemini_pro
#   remote with connection `projects/automated-style-411721/locations/us/connections/vertex_connection`
#   options (endpoint = 'gemini-pro');
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ##Part 1: Fill null values for MRDS Com_Types

# %% [markdown]
# ####Observe the data we are working with

# %%
# %%bigquery
# select * except (url, mrds_id, mas_id, latitude, longitude, state, county, data_source, load_time, county_predictions, mineral_type, type)
# from retails_stg.Mrds
# where commod1 is not null
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      Dep_ID                        site_name region        country com_type  \
# 0  10400538                Nichols Ranch ISL     NA  United States     None
# 1  10400618    Lisbon Valley Uranium Project     NA  United States     None
# 2  10305956       Michigan Au Mining Company     NA  United States        M
# 3  10307397  Unnamed (Don Miller Hills area)     NA  United States     None
# 4  10307907                   Johnston Creek     NA  United States     None
#
#    commod1                                            commod2 commod3
# 0  Uranium                                               None    None
# 1  Uranium                                               None    None
# 2     Gold                                               None    None
# 3     Zinc  Lead, Molybdenum, Silver, Iron, Copper, Barium...    None
# 4     Gold                                               None    None

# %%
# %%bigquery
# select count(*)
# from retails_stg.Mrds
# where com_type is null
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     f0_
# 0  3817

# %% [markdown]
# #### Test the generate_text function

# %%
# %%bigquery
# declare prompt_query STRING default "Suggest a commodity type for each site. Return the output as json, include the Dep_ID and com_type in the output";
# select *
# from ML.generate_text(
#   model remote_models.gemini_pro,
#   (
#     select concat(prompt_query, to_json_string(json_object("Dep_ID", Dep_ID, "site_name", site_name, "region", region,
#                   "country", country, "com_type", com_type, "commod1", commod1, "commod2", commod2, "commod3", commod3))) as prompt
#     from retails_stg.Mrds
#     order by Dep_ID
#     limit 10
#   ),
#   struct(TRUE as flatten_json_output)
# );
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          ml_generate_text_llm_result  \
# 0  ```json\n{"Dep_ID":10000001,"com_type":"M","co...
# 1  ```json\n[\n  {"Dep_ID":10000002,"com_type":"M...
# 2  ```json\n[\n  {\n    "Dep_ID": 10000003,\n    ...
# 3  ```json\n{"Dep_ID":10000004,"com_type":"M","co...
# 4  ```json\n{"Dep_ID":10000005,"com_type":"M","co...
# 5  ```json\n{"Dep_ID":10000006,"com_type":"M","co...
# 6  ```json\n[\n  {\n    "Dep_ID": 10000007,\n    ...
# 7  ```json\n[\n  {\n    "Dep_ID": 10000008,\n    ...
# 8  ```json\n{"Dep_ID":10000009,"com_type":"M","co...
# 9  ```json\n[\n  {\n    "Dep_ID": 10000010,\n    ...
#
#                          ml_generate_text_rai_result ml_generate_text_status  \
# 0  [{"category":1,"probability":1,"probability_sc...
# 1  [{"category":1,"probability":1,"probability_sc...
# 2  [{"category":1,"probability":1,"probability_sc...
# 3  [{"category":1,"probability":1,"probability_sc...
# 4  [{"category":1,"probability":1,"probability_sc...
# 5  [{"category":1,"probability":1,"probability_sc...
# 6  [{"category":1,"probability":1,"probability_sc...
# 7  [{"category":1,"probability":1,"probability_sc...
# 8  [{"category":1,"probability":1,"probability_sc...
# 9  [{"category":1,"probability":1,"probability_sc...
#
#                                               prompt
# 0  Suggest a commodity type for each site. Return...
# 1  Suggest a commodity type for each site. Return...
# 2  Suggest a commodity type for each site. Return...
# 3  Suggest a commodity type for each site. Return...
# 4  Suggest a commodity type for each site. Return...
# 5  Suggest a commodity type for each site. Return...
# 6  Suggest a commodity type for each site. Return...
# 7  Suggest a commodity type for each site. Return...
# 8  Suggest a commodity type for each site. Return...
# 9  Suggest a commodity type for each site. Return...

# %% [markdown]
# ####Tweak the prompt and save the output

# %%
# %%bigquery
# declare prompt_query STRING default "Suggest one commodity type for one dep_id. Return the output as json, include the Dep_ID and com_type in the output";
# create or replace table retails_stg_ai.com_type_predictions_raw_10 as
#   select *
#   from ML.generate_text(
#     model remote_models.gemini_pro,
#     (
#       select concat(prompt_query, to_json_string(json_object("Dep_ID", Dep_ID, "site_name", site_name, "region", region,
#               "country", country, "com_type", com_type, "commod1", commod1, "commod2", commod2, "commod3", commod3))) as prompt
#       from retails_stg.Mrds
#       where com_type is null
#       order by Dep_ID
#       limit 10
#     ),
#     struct(0 as temperature, 8192 as max_output_tokens, 0.0 as top_p, 1 as top_k, TRUE as flatten_json_output)
#   );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select ml_generate_text_llm_result, prompt
# from retails_stg_ai.com_type_predictions_raw_10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          ml_generate_text_llm_result  \
# 0  ```json\n{"Dep_ID":10000003,"com_type":"M","co...
# 1  ```json\n{"Dep_ID":10000007,"com_type":"M","co...
# 2  ```json\n{"Dep_ID":10000001,"com_type":"M","co...
# 3  ```json\n{"Dep_ID":10000005,"com_type":"M","co...
# 4  ```json\n{"Dep_ID":10000009,"com_type":"M","co...
# 5  ```json\n{"Dep_ID":10000010,"com_type":"M","co...
# 6  ```json\n{"Dep_ID":10000008,"com_type":"M","co...
# 7  ```json\n{"Dep_ID":10000002,"com_type":"M","co...
# 8  ```json\n{"Dep_ID":10000004,"com_type":"M","co...
# 9  ```json\n{"Dep_ID":10000006,"com_type":"M","co...
#
#                                               prompt
# 0  Suggest one commodity type for one dep_id. Ret...
# 1  Suggest one commodity type for one dep_id. Ret...
# 2  Suggest one commodity type for one dep_id. Ret...
# 3  Suggest one commodity type for one dep_id. Ret...
# 4  Suggest one commodity type for one dep_id. Ret...
# 5  Suggest one commodity type for one dep_id. Ret...
# 6  Suggest one commodity type for one dep_id. Ret...
# 7  Suggest one commodity type for one dep_id. Ret...
# 8  Suggest one commodity type for one dep_id. Ret...
# 9  Suggest one commodity type for one dep_id. Ret...

# %% [markdown]
# ####Format the output to proper json

# %%
# %%bigquery
# select ml_generate_text_llm_result, trim(replace(replace(replace(ml_generate_text_llm_result, '```json', ''), '```', ''), '\n', '')) as formated_result
# from retails_stg_ai.com_type_predictions_raw_10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          ml_generate_text_llm_result  \
# 0  ```json\n{"Dep_ID":10000003,"com_type":"M","co...
# 1  ```json\n{"Dep_ID":10000007,"com_type":"M","co...
# 2  ```json\n{"Dep_ID":10000001,"com_type":"M","co...
# 3  ```json\n{"Dep_ID":10000005,"com_type":"M","co...
# 4  ```json\n{"Dep_ID":10000009,"com_type":"M","co...
# 5  ```json\n{"Dep_ID":10000010,"com_type":"M","co...
# 6  ```json\n{"Dep_ID":10000008,"com_type":"M","co...
# 7  ```json\n{"Dep_ID":10000002,"com_type":"M","co...
# 8  ```json\n{"Dep_ID":10000004,"com_type":"M","co...
# 9  ```json\n{"Dep_ID":10000006,"com_type":"M","co...
#
#                                      formated_result
# 0  {"Dep_ID":10000003,"com_type":"M","commod1":"C...
# 1  {"Dep_ID":10000007,"com_type":"M","commod1":"L...
# 2  {"Dep_ID":10000001,"com_type":"M","commod1":"C...
# 3  {"Dep_ID":10000005,"com_type":"M","commod1":"G...
# 4  {"Dep_ID":10000009,"com_type":"M","commod1":"S...
# 5  {"Dep_ID":10000010,"com_type":"M","commod1":"C...
# 6  {"Dep_ID":10000008,"com_type":"M","commod1":"G...
# 7  {"Dep_ID":10000002,"com_type":"M","commod1":"C...
# 8  {"Dep_ID":10000004,"com_type":"M","commod1":"G...
# 9  {"Dep_ID":10000006,"com_type":"M","commod1":"C...

# %%
# %%bigquery
# create or replace table retails_stg_ai.com_type_predictions_formatted_10 as
#   select trim(replace(replace(replace(ml_generate_text_llm_result, '```json', ''), '```', ''), '\n', '')) as ml_generate_text_llm_result
#   from retails_stg_ai.com_type_predictions_raw_10
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select json_value(ml_generate_text_llm_result, '$.Dep_ID') as Dep_ID,
#   json_value(ml_generate_text_llm_result, '$.com_type') as com_type
# from retails_stg_ai.com_type_predictions_formatted_10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      Dep_ID com_type
# 0  10000001        M
# 1  10000008        M
# 2  10000009        M
# 3  10000003        M
# 4  10000004        M
# 5  10000002        M
# 6  10000006        M
# 7  10000005        M
# 8  10000010        M
# 9  10000007        M

# %% [markdown]
# ####Add the com_types field to the Mrds table

# %%
# %%bigquery
# alter table retails_stg.Mrds add column com_types_predictions string;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ####Update the Mrds records with the predicted com_type

# %%
# %%bigquery
# update retails_stg.Mrds set com_types_predictions =
#   (select json_value(ml_generate_text_llm_result, '$.com_type')
#    from retails_stg_ai.com_type_predictions_formatted_10
#    where Dep_ID = cast(json_value(ml_generate_text_llm_result, '$.Dep_ID') as int64))
# where 1=1
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ####Inspect the output

# %%
# %%bigquery
# select * except (url, mrds_id, mas_id, latitude, longitude, state, county, data_source, load_time, county_predictions, mineral_type, type)
# from retails_stg.Mrds
# where com_types_predictions is not null
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      Dep_ID              site_name region        country com_type  \
# 0  10000001       Lookout Prospect     NA  United States        M
# 1  10000002    Lucky Find Prospect     NA  United States        M
# 2  10000003    Mccullough Prospect     NA  United States        M
# 3  10000004        Lucky Jim Claim     NA  United States        M
# 4  10000005     Matilda Occurrence     NA  United States        M
# 5  10000006        Marion Prospect     NA  United States        M
# 6  10000007  Marble Heart Prospect     NA  United States        M
# 7  10000008  Morning Star Prospect     NA  United States        M
# 8  10000009        Monday Prospect     NA  United States        M
# 9  10000010  Miller Brothers Claim     NA  United States        M
#
#         commod1       commod2       commod3 com_types_predictions
# 0        Copper  Gold, Silver          None                     M
# 1        Copper          Gold          None                     M
# 2        Copper          None    Zinc, Gold                     M
# 3          Gold          None  Copper, Lead                     M
# 4          Gold          None          None                     M
# 5        Copper          None          Lead                     M
# 6          Lead          None          None                     M
# 7          Gold        Copper          Iron                     M
# 8        Silver          Gold          Lead                     M
# 9  Copper, Gold          None          None                     M

# %% [markdown]
# ####Apply at larger scale

# %%
# %%bigquery
# select count(*)
# from retails_stg.Mrds_10k
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      f0_
# 0  10000

# %%
# %%bigquery
# declare prompt_query STRING default "Suggest one commodity type for one dep_id. Return the output as json, include the Dep_ID and com_type in the output";
# create or replace table retails_stg_ai.com_type_predictions_raw_10k as
#   select *
#   from ML.generate_text(
#     model remote_models.gemini_pro,
#     (
#       select concat(prompt_query, to_json_string(json_object("Dep_ID", Dep_ID, "site_name", site_name, "region", region,
#               "country", country, "com_type", com_type, "commod1", commod1, "commod2", commod2, "commod3", commod3))) as prompt
#       from retails_stg.Mrds
#     ),
#     struct(0 as temperature, 8192 as max_output_tokens, 0.0 as top_p, 1 as top_k, TRUE as flatten_json_output)
#   );
# Out:
# Executing query with job ID: dee894c8-22c2-4ca4-8056-6caab26f8158
# Query executing: 3809.96s

# %%
# %%bigquery
# select creation_time, end_time, query
# from `region-us`.INFORMATION_SCHEMA.JOBS
# where job_id = 'a3dff4b9-1a00-4d16-8f65-26c160f1e3e7'

# %%
# %%bigquery
# create or replace table retails_stg_ai.com_type_predictions_formatted_10k as
#   select trim(replace(replace(replace(ml_generate_text_llm_result, '```json', ''), '```', ''), '\n', '')) as ml_generate_text_llm_result
#   from retails_stg_ai.com_type_predictions_raw_10k

# %%
# %%bigquery
# select count(*) as county_count
# from retails_stg_ai.com_type_predictions_formatted_10k

# %%
# %%bigquery
# select json_value(ml_generate_text_llm_result, '$.Dep_ID') as Dep_ID,
#   json_value(ml_generate_text_llm_result, '$.com_type') as com_types_predictions
# from retails_stg_ai.com_type_predictions_formatted_10k

# %%
# %%bigquery
# update retails_stg.Mrds set com_types_predictions =
#   (select json_value(ml_generate_text_llm_result, '$.com_type')
#    from retails_stg_ai.com_type_predictions_formatted_10k
#    where Dep_ID = cast(json_value(ml_generate_text_llm_result, '$.Dep_ID') as int64))
# where 1=1

# %%
# %%bigquery
# select *
# from retails_stg.Mrds
# where com_types_predictions is not null

# %%
# %%bigquery
# select commod1, com_types_predictions, count(*) as count
# from retails_stg.Mrds
# where com_types_predictions is not null
# group by commod1, com_types_predictions
# order by count(*) desc

# %%
# %%bigquery
# update retails_stg.Mrds
#   set data_source = 'usgs' where com_types_predictions is not null

# %% [markdown]
# ##Part 2: Fill null values for Mrds commod1

# %% [markdown]
# ####Observe the data we are working with

# %%
# %%bigquery
# select * except (url, mrds_id, mas_id, latitude, longitude, state, county, data_source, load_time, county_predictions, mineral_type, type, com_types_predictions)
# from retails_stg.Mrds
# where com_type is not null
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      Dep_ID                           site_name region        country  \
# 0  10306770               Daggett Hill Iron Pit     NA  United States
# 1  10306923       Columbus Area-Sand and Gravel     NA  United States
# 2  10400284                Silver King prospect     NA  United States
# 3  10310660                Original Amador Mine     NA  United States
# 4  10400312  Rundle, Mills, and Casler Property     NA  United States
#
#   com_type                        commod1    commod2 commod3
# 0        M                           Iron  Manganese    None
# 1        N  Sand and Gravel, Construction       None    None
# 2        M                           None       Gold    None
# 3        M                           Gold       None    None
# 4        M                       Tungsten       None    None

# %%
# %%bigquery
# select count(*)
# from retails_stg.Mrds
# where commod1 is null
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      f0_
# 0  21031

# %% [markdown]
# #### Test the generate_text function

# %%
# %%bigquery
# declare prompt_query STRING default "Suggest a primary commodity for each site. Return the output as json, include the Dep_ID and commod1 in the output";
# select *
# from ML.generate_text(
#   model remote_models.gemini_pro,
#   (
#     select concat(prompt_query, to_json_string(json_object("Dep_ID", Dep_ID, "site_name", site_name, "region", region,
#                   "country", country, "com_type", com_type, "commod1", commod1, "commod2", commod2, "commod3", commod3))) as prompt
#     from retails_stg.Mrds
#     where commod1 is null
#     order by Dep_ID
#     limit 10
#   ),
#   struct(TRUE as flatten_json_output)
# );
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          ml_generate_text_llm_result  \
# 0  ```json\n[\n  {\n    "Dep_ID": 10000620,\n    ...
# 1  ```json\n[\n  {\n    "Dep_ID": 10000634,\n    ...
# 2  ```json\n[\n  {\n    "Dep_ID": 10001351,\n    ...
# 3  ```json\n{"Dep_ID":10001971,"com_type":"M","co...
# 4  ```json\n{"Dep_ID":10001973,"com_type":"M","co...
# 5  ```json\n[\n  {\n    "Dep_ID": 10002009,\n    ...
# 6  ```json\n[\n  {\n    "Dep_ID": 10002033,\n    ...
# 7  ```json\n[\n  {\n    "Dep_ID": 10002115,\n    ...
# 8  ```json\n[\n  {\n    "Dep_ID": 10002383,\n    ...
# 9  ```json\n[\n  {\n    "Dep_ID": 10002406,\n    ...
#
#   ml_generate_text_rai_result ml_generate_text_status  \
# 0                        None
# 1                        None
# 2                        None
# 3                        None
# 4                        None
# 5                        None
# 6                        None
# 7                        None
# 8                        None
# 9                        None
#
#                                               prompt
# 0  Suggest a primary commodity for each site. Ret...
# 1  Suggest a primary commodity for each site. Ret...
# 2  Suggest a primary commodity for each site. Ret...
# 3  Suggest a primary commodity for each site. Ret...
# 4  Suggest a primary commodity for each site. Ret...
# 5  Suggest a primary commodity for each site. Ret...
# 6  Suggest a primary commodity for each site. Ret...
# 7  Suggest a primary commodity for each site. Ret...
# 8  Suggest a primary commodity for each site. Ret...
# 9  Suggest a primary commodity for each site. Ret...

# %% [markdown]
# ####Tweak the prompt and save the output

# %%
# %%bigquery
# declare prompt_query STRING default "Suggest one primary commodity for one site. Return the output as json, include the Dep_ID and commod1 in the output";
# create or replace table retails_stg_ai.commod1_predictions_raw_10 as
#   select *
#   from ML.generate_text(
#     model remote_models.gemini_pro,
#     (
#       select concat(prompt_query, to_json_string(json_object("Dep_ID", Dep_ID, "site_name", site_name, "region", region,
#                     "country", country, "com_type", com_type, "commod1", commod1, "commod2", commod2, "commod3", commod3))) as prompt
#       from retails_stg.Mrds
#       where commod1 is null
#       order by Dep_ID
#       limit 10
#     ),
#     struct(0 as temperature, 8192 as max_output_tokens, 0.0 as top_p, 1 as top_k, TRUE as flatten_json_output)
#   );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select ml_generate_text_llm_result, prompt
# from retails_stg_ai.commod1_predictions_raw_10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          ml_generate_text_llm_result  \
# 0  ```json\n{"Dep_ID":10001351,"com_type":"M","co...
# 1  ```json\n{"Dep_ID":10002033,"com_type":"M","co...
# 2  ```json\n{"Dep_ID":10000620,"com_type":"M","co...
# 3  ```json\n{"Dep_ID":10002383,"com_type":"M","co...
# 4  ```json\n{"Dep_ID":10001973,"com_type":"M","co...
# 5  ```json\n{"Dep_ID":10002406,"com_type":"M","co...
# 6  ```json\n{"Dep_ID":10002115,"com_type":"M","co...
# 7  ```json\n{"Dep_ID":10000634,"com_type":"M","co...
# 8  {"Dep_ID":10001971,"com_type":"M","commod1":nu...
# 9  ```json\n{"Dep_ID":10002009,"com_type":"B","co...
#
#                                               prompt
# 0  Suggest one primary commodity for one site. Re...
# 1  Suggest one primary commodity for one site. Re...
# 2  Suggest one primary commodity for one site. Re...
# 3  Suggest one primary commodity for one site. Re...
# 4  Suggest one primary commodity for one site. Re...
# 5  Suggest one primary commodity for one site. Re...
# 6  Suggest one primary commodity for one site. Re...
# 7  Suggest one primary commodity for one site. Re...
# 8  Suggest one primary commodity for one site. Re...
# 9  Suggest one primary commodity for one site. Re...

# %% [markdown]
# ####Format the output to proper json

# %%
# %%bigquery
# select ml_generate_text_llm_result, trim(replace(replace(replace(ml_generate_text_llm_result, '```json', ''), '```', ''), '\n', '')) as formated_result
# from retails_stg_ai.commod1_predictions_raw_10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          ml_generate_text_llm_result  \
# 0  ```json\n{"Dep_ID":10001351,"com_type":"M","co...
# 1  ```json\n{"Dep_ID":10002033,"com_type":"M","co...
# 2  ```json\n{"Dep_ID":10000620,"com_type":"M","co...
# 3  ```json\n{"Dep_ID":10002383,"com_type":"M","co...
# 4  ```json\n{"Dep_ID":10001973,"com_type":"M","co...
# 5  ```json\n{"Dep_ID":10002406,"com_type":"M","co...
# 6  ```json\n{"Dep_ID":10002115,"com_type":"M","co...
# 7  ```json\n{"Dep_ID":10000634,"com_type":"M","co...
# 8  {"Dep_ID":10001971,"com_type":"M","commod1":nu...
# 9  ```json\n{"Dep_ID":10002009,"com_type":"B","co...
#
#                                      formated_result
# 0  {"Dep_ID":10001351,"com_type":"M","commod1":"C...
# 1  {"Dep_ID":10002033,"com_type":"M","commod1":"T...
# 2  {"Dep_ID":10000620,"com_type":"M","commod1":"C...
# 3  {"Dep_ID":10002383,"com_type":"M","commod1":"C...
# 4  {"Dep_ID":10001973,"com_type":"M","commod1":"T...
# 5  {"Dep_ID":10002406,"com_type":"M","commod1":"C...
# 6  {"Dep_ID":10002115,"com_type":"M","commod1":"T...
# 7  {"Dep_ID":10000634,"com_type":"M","commod1":"L...
# 8  {"Dep_ID":10001971,"com_type":"M","commod1":nu...
# 9  {"Dep_ID":10002009,"com_type":"B","commod1":"C...

# %%
# %%bigquery
# create or replace table retails_stg_ai.commod1_predictions_formatted_10 as
#   select trim(replace(replace(replace(ml_generate_text_llm_result, '```json', ''), '```', ''), '\n', '')) as ml_generate_text_llm_result
#   from retails_stg_ai.commod1_predictions_raw_10
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select json_value(ml_generate_text_llm_result, '$.Dep_ID') as Dep_ID,
#   json_value(ml_generate_text_llm_result, '$.commod1') as commod1
# from retails_stg_ai.commod1_predictions_formatted_10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      Dep_ID         commod1
# 0  10001351          Copper
# 1  10001971            None
# 2  10001973        Tungsten
# 3  10000620          Copper
# 4  10002115   Tungsten, Tin
# 5  10002009        Chromium
# 6  10000634    Lead, Copper
# 7  10002033        Tungsten
# 8  10002383          Copper
# 9  10002406  Copper, Silver

# %% [markdown]
# ####Add the commod1 field to the Mrds table

# %%
# %%bigquery
# alter table retails_stg.Mrds add column commod1_predictions string;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ####Update the Mrds records with the predicted commod1

# %%
# %%bigquery
# update retails_stg.Mrds set commod1_predictions =
#   (select json_value(ml_generate_text_llm_result, '$.commod1')
#    from retails_stg_ai.commod1_predictions_formatted_10
#    where Dep_ID = cast(json_value(ml_generate_text_llm_result, '$.Dep_ID') as int64))
# where 1=1
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ####Inspect the output

# %%
# %%bigquery
# select * except (url, mrds_id, mas_id, latitude, longitude, state, county, data_source, load_time, county_predictions, mineral_type, type, com_types_predictions)
# from retails_stg.Mrds
# where commod1_predictions is not null
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      Dep_ID                       site_name region        country com_type  \
# 0  10000620       Little Caribou Occurrence     NA  United States        M
# 1  10000634               Ridgetop Prospect     NA  United States        M
# 2  10001351              Unnamed Occurrence     NA  United States        M
# 3  10001973              Unnamed Occurrence     NA  United States        M
# 4  10002009                       Cape Nome     NA  United States        B
# 5  10002033           Thompson Creek Placer     NA  United States        M
# 6  10002115  Upper Bonanza Creek Occurrence     NA  United States        M
# 7  10002383         Cascade Copper Prospect     NA  United States        M
# 8  10002406               Arms Copper Claim     NA  United States        M
#
#   commod1                                      commod2  \
# 0    None                       Copper, Antimony, Zinc
# 1    None                                 Lead, Copper
# 2    None                                         None
# 3    None                                         None
# 4    None  Chromium, Gold, Tungsten, Fluorine-Fluorite
# 5    None                                         None
# 6    None                                         None
# 7    None                                         None
# 8    None                                         None
#
#                        commod3 commod1_predictions
# 0                         None              Copper
# 1                         None        Lead, Copper
# 2                       Copper              Copper
# 3                     Tungsten            Tungsten
# 4  Chromium, Fluorine-Fluorite            Chromium
# 5                     Tungsten            Tungsten
# 6                Tungsten, Tin       Tungsten, Tin
# 7                       Copper              Copper
# 8               Copper, Silver      Copper, Silver

# %% [markdown]
# ####Apply at larger scale

# %%
# %%bigquery
# declare prompt_query STRING default "Suggest one primary commodity for one site. Return the output as json, include the Dep_ID and commod1 in the output";
# create or replace table retails_stg_ai.comomd1_predictions_raw_10k as
#   select *
#   from ML.generate_text(
#     model remote_models.gemini_pro,
#     (
#       select concat(prompt_query, to_json_string(json_object("Dep_ID", Dep_ID, "site_name", site_name, "region", region,
#                     "country", country, "com_type", com_type, "commod1", commod1, "commod2", commod2, "commod3", commod3))) as prompt
#       from retails_stg.Mrds
#       where commod1 is null
#     ),
#     struct(0 as temperature, 8192 as max_output_tokens, 0.0 as top_p, 1 as top_k, TRUE as flatten_json_output)
#   );

# %%
# %%bigquery
# select creation_time, end_time, query
# from `region-us`.INFORMATION_SCHEMA.JOBS
# where job_id = ''

# %%
# %%bigquery
# create or replace table retails_stg_ai.commod1_predictions_formatted_10k as
#   select trim(replace(replace(replace(ml_generate_text_llm_result, '```json', ''), '```', ''), '\n', '')) as ml_generate_text_llm_result
#   from retails_stg_ai.comomd1_predictions_raw_10k

# %%
# %%bigquery
# select count(*) as county_count
# from retails_stg_ai.commod1_predictions_formatted_10k

# %%
# %%bigquery
# select json_value(ml_generate_text_llm_result, '$.Dep_ID') as Dep_ID,
#   json_value(ml_generate_text_llm_result, '$.commod1') as commod1_predictions
# from retails_stg_ai.commod1_predictions_formatted_10k

# %%
# %%bigquery
# update retails_stg.Mrds set commod1_predictions =
#   (select json_value(ml_generate_text_llm_result, '$.commod1')
#    from retails_stg_ai.commod1_predictions_formatted_10k
#    where Dep_ID = cast(json_value(ml_generate_text_llm_result, '$.Dep_ID') as int64))
# where 1=1

# %%
# %%bigquery
# select *
# from retails_stg.Mrds
# where commod1_predictions is not null

# %%
# %%bigquery
# select com_type, commod1_predictions, count(*) as count
# from retails_stg.Mrds
# where commod1_predictions is not null
# group by com_type, commod1_predictions
# order by count(*) desc

# %%
# %%bigquery
# update retails_stg.Mrds
#   set data_source = 'usgs' where commod1_predictions is not null

# %% [markdown]
# ##Part 3: Fill null values for MRDS state

# %% [markdown]
# ####Observe the data we are working with

# %%
# %%bigquery
# select * except (url, mrds_id, mas_id, com_type, commod1, commod2, commod3, data_source, load_time, county_predictions, mineral_type, type, com_types_predictions, commod1_predictions)
# from retails_stg.Mrds
# where country is not null
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      Dep_ID                                        site_name  latitude  \
# 0  10307418                     Unnamed (Muklung Hills area)  59.29933
# 1  10311019                                  Blanca District  37.57169
# 2  10400147                                           Eliana  13.76692
# 3  10306988  Tri-State Brick and Tile Clay Mine-Hinds County  32.36768
# 4  10308367                                          Baggage  63.66976
#
#    longitude region        country        state    county
# 0 -158.30266     NA  United States       Alaska      None
# 1 -105.48779     NA  United States     Colorado  Costilla
# 2   75.71714     SA           Peru         None      None
# 3  -90.21675     NA  United States  Mississippi     Hinds
# 4 -141.10262     NA  United States       Alaska      None

# %%
# %%bigquery
# select count(*)
# from retails_stg.Mrds
# where state is null
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      f0_
# 0  12484

# %% [markdown]
# #### Test the generate_text function

# %%
# %%bigquery
# declare prompt_query STRING default "Suggest a state name for each site. Return the output as json, include the Dep_ID and state in the output";
# select *
# from ML.generate_text(
#   model remote_models.gemini_pro,
#   (
#     select concat(prompt_query, to_json_string(json_object("Dep_ID", Dep_ID, "site_name", site_name, "latitude", latitude,
#                   "longitude", longitude, "region", region, "country", country, "state", state, "county", county))) as prompt
#     from retails_stg.Mrds
#     where state is null
#     and country = 'United States' or country = 'Mexico' or country = 'Canada'
#     order by Dep_ID
#     limit 10
#   ),
#   struct(TRUE as flatten_json_output)
# );
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          ml_generate_text_llm_result  \
# 0                                               None
# 1                                               None
# 2  ```json\n{"Dep_ID":10008157,"country":"Mexico"...
# 3                                               None
# 4  ```json\n[\n  {\n    "Dep_ID": 10008159,\n    ...
# 5  ```json\n[\n  {\n    "Dep_ID": 10008160,\n    ...
# 6                                               None
# 7                                               None
# 8                                               None
# 9                                               None
#
#   ml_generate_text_rai_result ml_generate_text_status  \
# 0                        None
# 1                        None
# 2                        None
# 3                        None
# 4                        None
# 5                        None
# 6                        None
# 7                        None
# 8                        None
# 9                        None
#
#                                               prompt
# 0  Suggest a state name for each site. Return the...
# 1  Suggest a state name for each site. Return the...
# 2  Suggest a state name for each site. Return the...
# 3  Suggest a state name for each site. Return the...
# 4  Suggest a state name for each site. Return the...
# 5  Suggest a state name for each site. Return the...
# 6  Suggest a state name for each site. Return the...
# 7  Suggest a state name for each site. Return the...
# 8  Suggest a state name for each site. Return the...
# 9  Suggest a state name for each site. Return the...

# %% [markdown]
# ####Tweak the prompt and save the output

# %%
# %%bigquery
# declare prompt_query STRING default "Suggest one state or province for one site. Return the output as json, include the Dep_ID and state in the output";
# create or replace table retails_stg_ai.state_predictions_raw_10 as
#   select *
#   from ML.generate_text(
#     model remote_models.gemini_pro,
#     (
#         select concat(prompt_query, to_json_string(json_object("Dep_ID", Dep_ID, "site_name", site_name, "latitude", latitude,
#                     "longitude", longitude, "region", region, "country", country, "state", state, "county", county))) as prompt
#       from retails_stg.Mrds
#       where state is null
#       order by Dep_ID
#       limit 10
#     ),
#     struct(0 as temperature, 8192 as max_output_tokens, 0.0 as top_p, 1 as top_k, TRUE as flatten_json_output)
#   );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select ml_generate_text_llm_result, prompt
# from retails_stg_ai.state_predictions_raw_10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          ml_generate_text_llm_result  \
# 0                                               None
# 1  ```json\n{"Dep_ID":10003683,"country":"Botswan...
# 2  ```json\n{"Dep_ID":10003687,"country":"Botswan...
# 3  ```json\n{"Dep_ID":10003689,"country":"Botswan...
# 4  ```json\n{"Dep_ID":10003681,"country":"Algeria...
# 5                                               None
# 6                                               None
# 7  ```json\n{"Dep_ID":10003688,"country":"Botswan...
# 8  ```json\n{"Dep_ID":10003682,"country":"Burma",...
# 9  ```json\n{"Dep_ID":10003686,"country":"Botswan...
#
#                                               prompt
# 0  Suggest one state or province for one site. Re...
# 1  Suggest one state or province for one site. Re...
# 2  Suggest one state or province for one site. Re...
# 3  Suggest one state or province for one site. Re...
# 4  Suggest one state or province for one site. Re...
# 5  Suggest one state or province for one site. Re...
# 6  Suggest one state or province for one site. Re...
# 7  Suggest one state or province for one site. Re...
# 8  Suggest one state or province for one site. Re...
# 9  Suggest one state or province for one site. Re...

# %% [markdown]
# ####Format the output to proper json

# %%
# %%bigquery
# select ml_generate_text_llm_result, trim(replace(replace(replace(ml_generate_text_llm_result, '```json', ''), '```', ''), '\n', '')) as formated_result
# from retails_stg_ai.state_predictions_raw_10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          ml_generate_text_llm_result  \
# 0                                               None
# 1  ```json\n{"Dep_ID":10003683,"country":"Botswan...
# 2  ```json\n{"Dep_ID":10003687,"country":"Botswan...
# 3  ```json\n{"Dep_ID":10003689,"country":"Botswan...
# 4  ```json\n{"Dep_ID":10003681,"country":"Algeria...
# 5                                               None
# 6                                               None
# 7  ```json\n{"Dep_ID":10003688,"country":"Botswan...
# 8  ```json\n{"Dep_ID":10003682,"country":"Burma",...
# 9  ```json\n{"Dep_ID":10003686,"country":"Botswan...
#
#                                      formated_result
# 0                                               None
# 1  {"Dep_ID":10003683,"country":"Botswana","count...
# 2  {"Dep_ID":10003687,"country":"Botswana","count...
# 3  {"Dep_ID":10003689,"country":"Botswana","count...
# 4  {"Dep_ID":10003681,"country":"Algeria","county...
# 5                                               None
# 6                                               None
# 7  {"Dep_ID":10003688,"country":"Botswana","count...
# 8  {"Dep_ID":10003682,"country":"Burma","county":...
# 9  {"Dep_ID":10003686,"country":"Botswana","count...

# %%
# %%bigquery
# create or replace table retails_stg_ai.state_predictions_formatted_10 as
#   select trim(replace(replace(replace(ml_generate_text_llm_result, '```json', ''), '```', ''), '\n', '')) as ml_generate_text_llm_result
#   from retails_stg_ai.state_predictions_raw_10
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select json_value(ml_generate_text_llm_result, '$.Dep_ID') as Dep_ID,
#   json_value(ml_generate_text_llm_result, '$.state') as state_predictions
# from retails_stg_ai.state_predictions_formatted_10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      Dep_ID state_predictions
# 0      None              None
# 1      None              None
# 2      None              None
# 3  10003682              Shan
# 4  10003681             Adrar
# 5  10003687           Central
# 6  10003688          Gaborone
# 7  10003683           Central
# 8  10003686          Gaborone
# 9  10003689          Gaborone

# %% [markdown]
# ####Add the state field to the Mrds table

# %%
# %%bigquery
# alter table retails_stg.Mrds add column state_predictions string;

# %% [markdown]
# ####Update the Mrds records with the predicted state

# %%
# %%bigquery
# update retails_stg.Mrds set state_predictions =
#   (select json_value(ml_generate_text_llm_result, '$.state')
#    from retails_stg_ai.state_predictions_formatted_10
#    where Dep_ID = cast(json_value(ml_generate_text_llm_result, '$.Dep_ID') as int64))
# where 1=1

# %% [markdown]
# ####Inspect the output

# %%
# %%bigquery
# select * except (url, mrds_id, mas_id, com_type, commod1, commod2, commod3, data_source, load_time, county_predictions, mineral_type, type, com_types_predictions, commod1_predictions)
# from retails_stg.Mrds
# where state_predictions is not null

# %% [markdown]
# ####Apply at larger scale

# %%
# %%bigquery
# declare prompt_query STRING default "Suggest one state or province for one site. Return the output as json, include the Dep_ID and state in the output";
# create or replace table retails_stg_ai.state_predictions_raw_10k as
#   select *
#   from ML.generate_text(
#     model remote_models.gemini_pro,
#     (
#         select concat(prompt_query, to_json_string(json_object("Dep_ID", Dep_ID, "site_name", site_name, "latitude", latitude,
#                     "longitude", longitude, "region", region, "country", country, "state", state, "county", county))) as prompt
#       from retails_stg.Mrds
#       where state is null
#     ),
#     struct(0 as temperature, 8192 as max_output_tokens, 0.0 as top_p, 1 as top_k, TRUE as flatten_json_output)
#   );

# %%
# %%bigquery
# select creation_time, end_time, query
# from `region-us`.INFORMATION_SCHEMA.JOBS
# where job_id = ''

# %%
# %%bigquery
# create or replace table retails_stg_ai.state_predictions_formatted_10k as
#   select trim(replace(replace(replace(ml_generate_text_llm_result, '```json', ''), '```', ''), '\n', '')) as ml_generate_text_llm_result
#   from retails_stg_ai.state_predictions_raw_10k

# %%
# %%bigquery
# select count(*) as county_count
# from retails_stg_ai.state_predictions_formatted_10k

# %%
# %%bigquery
# select json_value(ml_generate_text_llm_result, '$.Dep_ID') as Dep_ID,
#   json_value(ml_generate_text_llm_result, '$.state') as state_predictions
# from retails_stg_ai.state_predictions_formatted_10k

# %%
# %%bigquery
# update retails_stg.Mrds set state_predictions =
#   (select json_value(ml_generate_text_llm_result, '$.state')
#    from retails_stg_ai.state_predictions_formatted_10k
#    where Dep_ID = cast(json_value(ml_generate_text_llm_result, '$.Dep_ID') as int64))
# where 1=1

# %%
# %%bigquery
# select *
# from retails_stg.Mrds
# where state_predictions is not null

# %%
# %%bigquery
# select country, state_predictions, count(*) as count
# from retails_stg.Mrds
# where state_predictions is not null
# group by country, state_predictions
# order by count(*) desc

# %%
# %%bigquery
# update retails_stg.Mrds
#   set data_source = 'usgs' where state_predictions is not null

# %% [markdown]
# ## Part 4: Parts.material

# %% [markdown]
# ### Observe the data we are working with

# %%
# %%bigquery
# select * except (size_description, p_size, p_brand, p_name, p_container, p_mfgr, p_retailprice, data_source, load_time, p_comment)
# from retails_stg.Parts
# where material is not null
# limit 10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    p_partkey material materials_predictions
# 0      84151   NICKEL                  None
# 1      71794      TIN                  None
# 2      77224   COPPER                  None
# 3      82043    STEEL                  None
# 4     129293    BRASS                  None
# 5     196804   COPPER                  None
# 6      82788    STEEL                  None
# 7     199530      TIN                  None
# 8     158424      TIN                  None
# 9      37120      TIN                  None

# %%
# %%bigquery
# SELECT *
# FROM retails_stg.Parts
# WHERE
# p_partkey IS NULL OR
#
# p_size IS NULL OR
# p_brand IS NULL OR
# p_name IS NULL OR
# p_container IS NULL OR
# p_mfgr IS NULL OR
# p_retailprice IS NULL OR
# size_description IS NULL OR
# material IS NULL OR
#
# data_source IS NULL OR
# load_time IS NULL OR
# p_comment IS NULL;
# Out:
# Query is running:   0%|          |
# Downloading: |          |
# Empty DataFrame
# Columns: [p_partkey, size_description, material, p_size, p_brand, p_name, p_container, p_mfgr, p_retailprice, p_comment, data_source, load_time, materials_predictions]
# Index: []

# %%
# %%bigquery
#
# DECLARE prompt_query STRING DEFAULT "Suggest a material and size description for each p_partkey. Also, generate an additional attribute for this part. Return the output as JSON, including the partkey, material, and the generated attribute.";
#
# SELECT
#   p.p_partkey,
#   p.size_description,
#   p.p_size,
#   p.p_brand,
#   p.p_mfgr,
#   p.p_retailprice,
#   p.p_comment,
#   ml.generated_text
# FROM
#   retails_stg.Parts p
# LEFT JOIN UNNEST(ML.GENERATE_TEXT(
#   MODEL `your-project-id.your_dataset.your_model`,
#   (
#     SELECT
#       CONCAT(
#         prompt_query,
#         TO_JSON_STRING(
#           JSON_OBJECT(
#             "p_partkey", p_partkey,
#             "size_description", size_description,
#             "p_size", p_size,
#             "p_brand", p_brand,
#             "p_mfgr", p_mfgr,
#             "p_brand", p_brand,
#             "p_retailprice", p_retailprice,
#             "p_comment", p_comment
#           )
#         )
#       ) AS prompt
#     FROM
#       retails_stg.Parts
#     WHERE
#       p.p_partkey = p_partkey
#     LIMIT 1
#   ),
#   STRUCT(TRUE AS flatten_json_output)
# )) ml
# ORDER BY
#   p.p_partkey
# LIMIT 10;
# Out:
# Executing query with job ID: b631b537-d544-452f-a46d-04f77dd906b4
# Query executing: 0.27s
# ERROR:
#  400 Syntax error: Expected ")" but got identifier "remote_models" at [14:7]
#
# Location: US
# Job ID: b631b537-d544-452f-a46d-04f77dd906b4

# %% [markdown]
# ### Tweak the generate_text function

# %%
# %%bigquery
# declare prompt_query STRING default "Suggest a rare material for one part. Return the output as json, include the p_partkey and material in the output";
# create or replace table retails_stg_ai.materials_predictions_raw_10 as
#   select *
#   from ML.generate_text(
#     model remote_models.gemini_pro,
#     (
#       select concat(prompt_query, to_json_string(json_object("p_partkey", p_partkey, "size_description", size_description, "p_size", p_size,
#             "p_brand", p_brand, "p_mfgr", p_mfgr, "p_brand", p_brand, "p_retailprice", p_retailprice, "p_comment", p_comment))) as prompt
#       from retails_stg.Parts
#       where material is null and size_description is not null
#       order by p_partkey
#       limit 10
#     ),
#     struct(0 as temperature, 8192 as max_output_tokens, 0.0 as top_p, 1 as top_k, TRUE as flatten_json_output)
#   );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select ml_generate_text_llm_result, prompt
# from retails_stg_ai.materials_predictions_raw_10
# Out:
# Query is running:   0%|          |
# Downloading: |          |
# Empty DataFrame
# Columns: [ml_generate_text_llm_result, prompt]
# Index: []

# %% [markdown]
# ### Format the output to prosper json

# %%
# %%bigquery
# select ml_generate_text_llm_result, trim(replace(replace(replace(ml_generate_text_llm_result, '```json', ''), '```', ''), '\n', '')) as formated_result
# from retails_stg_ai.materials_predictions_raw_10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          ml_generate_text_llm_result  \
# 0  ```json\n{"p_partkey":6,"material":"Osmium"}\n```
# 1  ```json\n{"p_partkey":5,"material":"Bamboo"}\n...
# 2  ```json\n{"p_partkey": 9, "material": "Unobtai...
# 3  ```json\n{"p_partkey": 3, "material": "Unobtai...
# 4  ```json\n{"p_partkey":7,"material":"Iridium"}\...
# 5  ```json\n{"p_partkey": 1, "material": "Unobtai...
# 6  ```json\n{"p_partkey":2, "material":"Unobtaini...
# 7  ```json\n{"p_partkey": 8, "material": "Unobtai...
# 8  ```json\n{"p_partkey":4,"material":"Unobtainiu...
# 9  ```json\n{"p_partkey": 10, "material": "Unobta...
#
#                                      formated_result
# 0                {"p_partkey":6,"material":"Osmium"}
# 1  {"p_partkey":5,"material":"Bamboo"} This respo...
# 2  {"p_partkey": 9, "material": "Unobtainium"} Un...
# 3  {"p_partkey": 3, "material": "Unobtainium"} Un...
# 4               {"p_partkey":7,"material":"Iridium"}
# 5        {"p_partkey": 1, "material": "Unobtainium"}
# 6  {"p_partkey":2, "material":"Unobtainium"} Unob...
# 7  {"p_partkey": 8, "material": "Unobtainium"} Un...
# 8           {"p_partkey":4,"material":"Unobtainium"}
# 9  {"p_partkey": 10, "material": "Unobtainium"} U...

# %%
# %%bigquery
# SELECT
# ml_generate_text_llm_result
# FROM
# retails_stg_ai.materials_predictions_raw_10
# WHERE
# ml_generate_text_llm_result IS NOT NULL
# LIMIT 10;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          ml_generate_text_llm_result
# 0  ```json\n{"p_partkey":6,"material":"Osmium"}\n```
# 1  ```json\n{"p_partkey":5,"material":"Bamboo"}\n...
# 2  ```json\n{"p_partkey": 9, "material": "Unobtai...
# 3  ```json\n{"p_partkey": 3, "material": "Unobtai...
# 4  ```json\n{"p_partkey":7,"material":"Iridium"}\...
# 5  ```json\n{"p_partkey": 1, "material": "Unobtai...
# 6  ```json\n{"p_partkey":2, "material":"Unobtaini...
# 7  ```json\n{"p_partkey": 8, "material": "Unobtai...
# 8  ```json\n{"p_partkey":4,"material":"Unobtainiu...
# 9  ```json\n{"p_partkey": 10, "material": "Unobta...

# %%
# %%bigquery
# SELECT
# CAST(REGEXP_EXTRACT(ml_generate_text_llm_result, r'"p_partkey": (\d+)') AS INT64) AS p_partkey,
# TRIM(REGEXP_EXTRACT(ml_generate_text_llm_result, r'"material": "([^"]*)"')) AS material
# FROM
# retails_stg_ai.materials_predictions_raw_10;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    p_partkey     material
# 0          3  Unobtainium
# 1       <NA>         None
# 2       <NA>         None
# 3       <NA>         None
# 4       <NA>         None
# 5       <NA>         None
# 6       <NA>         None
# 7       <NA>         None
# 8          8      Iridium
# 9       <NA>         None

# %% [markdown]
# ###Add material field to Parts table

# %%
# %%bigquery
# alter table retails_stg.Parts add column materials_predictions string;
# Out:
# Executing query with job ID: 4fa0957d-b44a-4583-b886-3f14618169bd
# Query executing: 0.50s
# ERROR:
#  400 Column already exists: materials_predictions at [1:42]
#
# Location: US
# Job ID: 4fa0957d-b44a-4583-b886-3f14618169bd

# %% [markdown]
# ### Update the Parts records with the predicted materials

# %%
# %%bigquery
# UPDATE retails_stg.Parts p
# SET materials_predictions = (
# SELECT json_value(ml_generate_text_llm_result, '$.material')
# FROM retails_stg_ai.com_type_predictions_formatted_10 ai
# WHERE cast(json_value(ml_generate_text_llm_result, '$.p_partkey') as int64) = p.p_partkey
# )
# WHERE EXISTS (
# SELECT 1
# FROM retails_stg_ai.com_type_predictions_formatted_10 ai
# WHERE cast(json_value(ml_generate_text_llm_result, '$.p_partkey') as int64) = p.p_partkey
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_0.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('count()')

# %% [markdown]
# ### Insepect the output

# %%
# %%bigquery
# select * except (size_description, p_size, p_brand, p_name, p_container, p_mfgr, p_retailprice, data_source, load_time, p_comment, materials_predictions)
# from retails_stg.Parts
# where materials_predictions is null
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#         p_partkey material
# 0          141449      TIN
# 1           88272      TIN
# 2          199424      TIN
# 3          158424      TIN
# 4           55758      TIN
# ...           ...      ...
# 199995      93978   NICKEL
# 199996      50773   NICKEL
# 199997      29036   NICKEL
# 199998     108798   NICKEL
# 199999      96380   NICKEL
#
# [200000 rows x 2 columns]

# %% [markdown]
# ### Apply at a larger scale

# %%
# %%bigquery
# SELECT count(*) as total_rows
# FROM retails_stg.Parts;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    total_rows
# 0      200000

# %% [markdown]
# ## Part 5 : supplier.area_code

# %% [markdown]
# ### observe the data we are working with
# fill the null values for areacode for merged supplier

# %%
# %%bigquery
# select * except (s_nationkey, load_time, s_name)
# from retails_stg.Supplier
# where area_code is not null
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    s_suppkey                                          s_comment  \
# 0         57  blithely regular excuses haggle of the careful...
# 1       2101  bold excuses nag among the fluffy packages. bl...
# 2       3790         dependencies haggle fluffily slyly regular
# 3       1820  fluffily final excuses use above the furiously...
# 4       9883                       slyly silent excuses within
#
#                               s_address area_code phone_number  s_acctbal  \
# 0             oMv1GPNlQ873mLt3G6TbaTiBn       100     510-7176    9200.46
# 1      b9nbtxAqjlxeOZu8QcBHijQhXQM7zfKl       100     309-3812    3389.46
# 2                           UH1,ReFsf8e       100     811-5774    7109.91
# 3  FuRNFCTOX2md01qjXYFBMFRSxCMaAQh9W4fj       100     383-1466    9912.52
# 4      iEILVgbCREGmcdVQ6rvKfpFwCeToFXGi       100     133-5786    6914.76
#
#   data_source area_code_predictions
# 0        bird                  None
# 1        bird                  None
# 2        bird                  None
# 3        bird                  None
# 4        bird                  None

# %%
# Out:
# Executing query with job ID: b49ea0b1-2aba-4551-8724-519c50f8d88a
# Query executing: 0.22s
# ERROR:
#  400 Syntax error: Unexpected ")" at [1:109]
#
# Location: US
# Job ID: b49ea0b1-2aba-4551-8724-519c50f8d88a

# %% [markdown]
# ### Test the generate_text function

# %%
# %%bigquery
# declare prompt_query STRING default "Suggest a new area_code for each supply key. Return the output as json, include the s_suppkey and area_code in the output";
# select *
# from ML.generate_text(
#   model remote_models.gemini_pro,
#   (
#     select concat(prompt_query, to_json_string(json_object("s_suppkey", s_suppkey, "s_nationkey", s_nationkey, "s_comment", s_comment,
#                   "s_name", s_name, "s_address", s_address, "area_code", area_code, "phone_number", phone_number, "s_acctbal", s_acctbal))) as prompt
#     from retails_stg.Supplier
#
#     order by s_suppkey
#     limit 10
#   ),
#   struct(TRUE as flatten_json_output)
# );
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          ml_generate_text_llm_result  \
# 0  ```json\n{"area_code":"800","phone_number":"80...
# 1  ```json\n{"area_code":"348","s_suppkey":2},\n{...
# 2  ```json\n[\n  {\n    "area_code": "471",\n    ...
# 3  ```json\n[\n  {\n    "area_code": "893",\n    ...
# 4  ```json\n[\n  {\n    "area_code": "752",\n    ...
# 5  ```json\n[\n  {\n    "s_suppkey": 6,\n    "are...
# 6  ```json\n[\n  {\n    "area_code": "400",\n    ...
# 7  ```json\n{"area_code":"893","s_suppkey":8},\n{...
# 8    ```json\n{"area_code":"277","s_suppkey":9}\n```
# 9   ```json\n{"area_code":"454","s_suppkey":10}\n```
#
#                          ml_generate_text_rai_result ml_generate_text_status  \
# 0  [{"category":1,"probability":1,"probability_sc...
# 1  [{"category":1,"probability":1,"probability_sc...
# 2  [{"category":1,"probability":1,"probability_sc...
# 3  [{"category":1,"probability":1,"probability_sc...
# 4  [{"category":1,"probability":1,"probability_sc...
# 5  [{"category":1,"probability":1,"probability_sc...
# 6  [{"category":1,"probability":1,"probability_sc...
# 7  [{"category":1,"probability":1,"probability_sc...
# 8  [{"category":1,"probability":1,"probability_sc...
# 9  [{"category":1,"probability":1,"probability_sc...
#
#                                               prompt
# 0  Suggest a new area_code for each supply key. R...
# 1  Suggest a new area_code for each supply key. R...
# 2  Suggest a new area_code for each supply key. R...
# 3  Suggest a new area_code for each supply key. R...
# 4  Suggest a new area_code for each supply key. R...
# 5  Suggest a new area_code for each supply key. R...
# 6  Suggest a new area_code for each supply key. R...
# 7  Suggest a new area_code for each supply key. R...
# 8  Suggest a new area_code for each supply key. R...
# 9  Suggest a new area_code for each supply key. R...

# %% [markdown]
# ###Tweak the prompt and save the output

# %%
# %%bigquery
# declare prompt_query STRING default "Suggest an area_code for each supply key. Return the output as json, include the s_suppkey and area_code in the output";
# create or replace table retails_stg_ai.area_code_predictions_raw_10 as
# select *
# from ML.generate_text(
#   model remote_models.gemini_pro,
#   (
#     select concat(prompt_query, to_json_string(json_object("s_suppkey", s_suppkey, "s_nationkey", s_nationkey, "s_comment", s_comment,
#                   "s_name", s_name, "s_address", s_address, "area_code", area_code, "phone_number", phone_number, "s_acctbal", s_acctbal))) as prompt
#     from retails_stg.Supplier
#
#     order by s_suppkey
#     limit 10
#     ),
#     struct(0 as temperature, 8192 as max_output_tokens, 0.0 as top_p, 1 as top_k, TRUE as flatten_json_output)
#   );
# Out:
# Executing query with job ID: a0f34da6-4b67-41d7-b9d2-c6b17b192309
# Query executing: 20.22s

# %% [markdown]
# ###Format the output to proper json

# %%
# %%bigquery
#
# select ml_generate_text_llm_result, trim(replace(replace(replace(ml_generate_text_llm_result, '```json', ''), '```', ''), '\n', '')) as formated_result
# from retails_stg_ai.area_code_predictions_raw_10

# %% [markdown]
# ###Add the commod type field to the merged_geographical_data table

# %%
# %%bigquery
# alter table retails_stg.Supplier add column area_code_predictions string;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ###Update the Supplier table

# %%
# %%bigquery
# update retails_stg.Supplier set area_code_predictions =
#   (select json_value(ml_generate_text_llm_result, '$.area_code')
#    from retails_stg_ai.com_type_predictions_formatted_10
#    where s_suppkey = cast(json_value(ml_generate_text_llm_result, '$.s_suppkey') as int64))
# where 1=1
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ###Inspect the output

# %%
# %%bigquery
# select * except (s_nationkey, load_time, s_name)
# from retails_stg.Supplier
# where area_code_predictions is not null
# Out:
# Query is running:   0%|          |
# Downloading: |          |
# Empty DataFrame
# Columns: [s_suppkey, s_comment, s_address, area_code, phone_number, s_acctbal, data_source, area_code_predictions]
# Index: []

# %% [markdown]
# ###Apply at a larger scale

# %%
# %%bigquery
# declare prompt_query STRING default "Suggest one address or phone_number for one supplier. Return the output as json, include the s_suppkey and area_code in the output";
# create or replace table retails_stg_ai.state_predictions_raw_10k as
#   select *
#   from ML.generate_text(
#     model remote_models.gemini_pro,
#     (
#         select concat(prompt_query, to_json_string(json_object("s_suppkey", s_suppkey, "s_nationkey", s_nationkey, "s_comment", s_comment,
#                   "s_name", s_name, "s_address", s_address, "area_code", area_code, "phone_number", phone_number, "s_acctbal", s_acctbal))) as prompt
#       from retails_stg.Supplier
#       where area_code is null
#     ),
#     struct(0 as temperature, 8192 as max_output_tokens, 0.0 as top_p, 1 as top_k, TRUE as flatten_json_output)
#   );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select s_name, area_code_predictions, count(*) as count
# from retails_stg.Supplier
# where area_code_predictions is not null
# group by s_name, area_code_predictions
# order by count(*) desc
# Out:
# Query is running:   0%|          |
# Downloading: |          |
# Empty DataFrame
# Columns: [s_name, area_code_predictions, count]
# Index: []

# %%
# %%bigquery
# select *
# from retails_stg.Supplier
# where area_code is not null
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#       s_suppkey s_nationkey  \
# 0            57           1
# 1          2101           1
# 2          3790          12
# 3          1820          13
# 4          9883          13
# ...         ...         ...
# 9995       8161          13
# 9996       7134          13
# 9997       3803          21
# 9998       4363          22
# 9999       8606          23
#
#                                               s_comment              s_name  \
# 0     blithely regular excuses haggle of the careful...  Supplier#000000057
# 1     bold excuses nag among the fluffy packages. bl...  Supplier#000002101
# 2            dependencies haggle fluffily slyly regular  Supplier#000003790
# 3     fluffily final excuses use above the furiously...  Supplier#000001820
# 4                          slyly silent excuses within   Supplier#000009883
# ...                                                 ...                 ...
# 9995  carefully special foxes haggle furiously again...  Supplier#000008161
# 9996  quickly pending grouches against the special d...  Supplier#000007134
# 9997  carefully ironic deposits nag above the carefu...  Supplier#000003803
# 9998                 quickly silent requests wake furio  Supplier#000004363
# 9999  slyly pending ideas affix requests. blithely i...  Supplier#000008606
#
#                                    s_address area_code phone_number  \
# 0                  oMv1GPNlQ873mLt3G6TbaTiBn       100     510-7176
# 1           b9nbtxAqjlxeOZu8QcBHijQhXQM7zfKl       100     309-3812
# 2                                UH1,ReFsf8e       100     811-5774
# 3       FuRNFCTOX2md01qjXYFBMFRSxCMaAQh9W4fj       100     383-1466
# 4           iEILVgbCREGmcdVQ6rvKfpFwCeToFXGi       100     133-5786
# ...                                      ...       ...          ...
# 9995              vHXXLZZpW dSWeSzAT2QG l5rP       999     101-6464
# 9996  7Qi6cgmKoDZ45wpDbTEQUS2pHXh6wbS0yQi,z9       999     701-6541
# 9997                      YCCOFfxNYIpQOgy88T       999     529-6934
# 9998  duR9ZJrhsEyJQENfaTRaXvbi14lkvY9wmgnXyl       999     420-8940
# 9999              AH,oFG0hlO0l4TmZgyKhq4lBxM       999     125-7679
#
#       s_acctbal data_source                        load_time  \
# 0       9200.46        bird 2024-02-02 22:02:46.597115+00:00
# 1       3389.46        bird 2024-02-02 22:02:46.597115+00:00
# 2       7109.91        bird 2024-02-02 22:02:46.597115+00:00
# 3       9912.52        bird 2024-02-02 22:02:46.597115+00:00
# 4       6914.76        bird 2024-02-02 22:02:46.597115+00:00
# ...         ...         ...                              ...
# 9995    9521.51        bird 2024-02-02 22:02:46.597115+00:00
# 9996    3774.98        bird 2024-02-02 22:02:46.597115+00:00
# 9997    7089.73        bird 2024-02-02 22:02:46.597115+00:00
# 9998    -846.76        bird 2024-02-02 22:02:46.597115+00:00
# 9999    1476.93        bird 2024-02-02 22:02:46.597115+00:00
#
#      area_code_predictions
# 0                     None
# 1                     None
# 2                     None
# 3                     None
# 4                     None
# ...                    ...
# 9995                  None
# 9996                  None
# 9997                  None
# 9998                  None
# 9999                  None
#
# [10000 rows x 11 columns]

# %%
# %%bigquery
# select creation_time, end_time, query
# from `region-us`.INFORMATION_SCHEMA.JOBS
# where job_id = ''
# Out:
# Query is running:   0%|          |
# Downloading: |          |
# Empty DataFrame
# Columns: [creation_time, end_time, query]
# Index: []

# %% [markdown]
# ## Part 6: Merge Changes into target table

# %% [markdown]
# ####Mrds table

# %%
# %%bigquery
# create or replace table retails_csp.Mrds_copy as select * from retails_csp.Mrds
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# alter table retails_csp.Mrds
#   add column com_types_predictions string;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# alter table retails_csp.Mrds
#   add column commod1_predictions string;
# Out:
# Executing query with job ID: d62909de-d566-411a-bce0-5349b637b38e
# Query executing: 0.35s
# ERROR:
#  400 Column already exists: mineral_type at [2:14]
#
# Location: US
# Job ID: d62909de-d566-411a-bce0-5349b637b38e

# %%
# %%bigquery
# alter table retails_csp.Mrds
#   add column state_predictions string;

# %%
# %%bigquery
# declare current_ts TIMESTAMP;
# set current_ts = current_timestamp();
#
# create temp table updates as
#   select s.*
#   from retails_csp.Mrds t join retails_stg.Mrds s
#   on t.Dep_ID = s.Dep_ID
#   where s.com_types_predictions != t.com_types_predictions
#   or s.commod1_predictions != t.commod1_predictions
#   or s.state_predictions != t.state_predictions;
#
# update retails_csp.Mrds
# set discontinue_time = timestamp_sub(current_ts, interval 1 second), status_flag = false
# where Dep_ID in (select Dep_ID from updates);
#
# insert into retails_csp.Mrds
#   (Dep_id, url, mrds_id, mas_id, site_name, latitude, longitude, region,
#     country, state, county, com_type, commod1, commod2, commod3, mineral_type, county_predictions, com_types_predictions, commod1_predictions, state_predictions, data_source, load_time, effective_time, status_flag)
#     (select Dep_id, url, mrds_id, mas_id, site_name, latitude, longitude, region,
#       country, state, county, com_type, commod1, commod2, commod3, mineral_type, county_predictions, com_types_predictions, commod1_predictions, state_predictions, data_source, load_time, current_ts, true
#       from updates);
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select count(*) as num_records
# from retails_csp.Mrds
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    num_records
# 0       304632

# %% [markdown]
# #### Parts table

# %%
# %%bigquery
# create or replace table retails_csp.Parts_copy as select * from retails_csp.Parts
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# alter table retails_csp.Parts
#   add column materials_predictions string;
# Out:
# Executing query with job ID: 8d069ff3-c14e-428a-b033-6d9e59eb84d9
# Query executing: 0.38s
# ERROR:
#  400 Column already exists: materials_predictions at [2:14]
#
# Location: US
# Job ID: 8d069ff3-c14e-428a-b033-6d9e59eb84d9

# %%
# %%bigquery
# declare current_ts TIMESTAMP;
# set current_ts = current_timestamp();
#
# create temp table updates as
#   select s.*
#   from retails_csp.Parts t join retails_stg.Parts s
#   on t.p_partkey = s.p_partkey
#   where s.materials_predictions != t.materials_predictions;
#
# update retails_csp.Parts
# set discontinue_time = timestamp_sub(current_ts, interval 1 second), status_flag = false
# where p_partkey in (select p_partkey from updates);
#
# insert into retails_csp.Parts
#   (p_partkey, size_description, material, p_size, p_brand, p_name, p_container, p_mfgr,
#     p_retailprice, p_comment, materials_predictions, data_source, load_time, effective_time, status_flag)
#     (select p_partkey, size_description, material, p_size, p_brand, p_name, p_container, p_mfgr,
#       p_retailprice, p_comment, materials_predictions, data_source, load_time, current_ts, true
#       from updates);
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select count(*) as num_records
# from retails_csp.Parts
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    num_records
# 0       200000

# %% [markdown]
# ####Supplier Table

# %%
# %%bigquery
# create or replace table retails_csp.Supplier_copy as select * from retails_csp.Supplier
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# alter table retails_csp.Supplier
#   add column area_code_predictions string;
# Out:
# Executing query with job ID: 00accf4b-f328-4afa-b975-b4693a5d1083
# Query executing: 0.40s
# ERROR:
#  400 Column already exists: area_code_predictions at [2:14]
#
# Location: US
# Job ID: 00accf4b-f328-4afa-b975-b4693a5d1083

# %%
# %%bigquery
# declare current_ts TIMESTAMP;
# set current_ts = current_timestamp();
#
# create temp table updates as
#   select s.*
#   from retails_csp.Supplier t join retails_stg.Supplier s
#   on t.s_suppkey = s.s_suppkey
#   where s.area_code_predictions != t.area_code_predictions;
#
# update retails_csp.Supplier
# set discontinue_time = timestamp_sub(current_ts, interval 1 second), status_flag = false
# where s_suppkey in (select s_suppkey from updates);
#
# insert into retails_csp.Supplier
#   (s_suppkey, s_nationkey, s_comment, s_name, s_address, area_code, phone_number, s_acctbal, area_code_predictions, data_source, load_time, effective_time, status_flag)
#     (select s_suppkey, s_nationkey, s_comment, s_name, s_address, area_code, phone_number, s_acctbal, area_code_predictions, data_source, load_time, current_ts, true
#       from updates);
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select count(*) as num_records
# from retails_csp.Supplier
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    num_records
# 0        10000
