# %% [markdown]
# ## Data Enrichment with AI

# %% [markdown]
# ### Setup

# %% [markdown]
# ##### Create a dataset for storing the AI tables and another for storing the AI models

# %%
# %%bigquery
# CREATE SCHEMA `automated-style-411721`.retails_stg_ai
# Out:
# Executing query with job ID: 6e8ee8f3-0407-45ba-9a5d-47787e9d76f6
# Query executing: 0.59s
# ERROR:
#  409 Already Exists: Dataset automated-style-411721:retails_stg_ai
#
# Location: US
# Job ID: 6e8ee8f3-0407-45ba-9a5d-47787e9d76f6

# %%
# %%bigquery
# CREATE SCHEMA `automated-style-411721`.remote_models;
# Out:
# Executing query with job ID: ba22e544-7f88-40bc-8cb7-9e4e6ac1c6c9
# Query executing: 0.36s
# ERROR:
#  409 Already Exists: Dataset automated-style-411721:remote_models
#
# Location: US
# Job ID: ba22e544-7f88-40bc-8cb7-9e4e6ac1c6c9

# %% [markdown]
# ##### Before running this cell, create the remote connection and assign the IAM role `Vertex AI User` to the service account associated with the connection.

# %%
# %%bigquery
# create or replace model remote_models.gemini_pro
#   remote with connection `projects/automated-style-411721/locations/us/connections/vertex_connection`
#   options (endpoint = 'gemini-pro');
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Part 1: Predict the county of sites

# %%
# %%bigquery
# select * except (com_type, commod1, commod2, commod3, data_source, load_time)
# from retails_stg.Mrds
# where latitude is not null
# and longitude is not null
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      Dep_ID                                                url mrds_id mas_id  \
# 0  10306836  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None   None
# 1  10306848  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None   None
# 2  10306849  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None   None
# 3  10306852  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None   None
# 4  10307124  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None   None
#
#             site_name  latitude  longitude region        country  \
# 0  Milton Silver Mine  44.52727  -68.22983     NA  United States
# 1       West Bay Mine  44.48659  -68.04614     NA  United States
# 2     Boss O' the Bay  44.47670  -68.16378     NA  United States
# 3      Manhattan Mine  44.36453  -68.74084     NA  United States
# 4             Johnson  34.71234  -81.90956     NA  United States
#
#             state       county
# 0           Maine      Hancock
# 1           Maine      Hancock
# 2           Maine      Hancock
# 3           Maine      Hancock
# 4  South Carolina  Spartanburg

# %% [markdown]
# #### Test the generate_text function

# %%
# %%bigquery
# declare prompt_query STRING default "Suggest a county for each site. Return the output as json, include the Dep_ID and county in the output";
# select *
# from ML.generate_text(
#   model remote_models.gemini_pro,
#   (
#     select concat(prompt_query, to_json_string(json_object("Dep_ID", Dep_ID, "site_name", site_name, "latitude", latitude,
#                   "longitude", longitude, "region", region, "country", country, "state", state))) as prompt
#     from retails_stg.Mrds
#     order by Dep_ID
#     limit 10
#   ),
#   struct(TRUE as flatten_json_output)
# );
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          ml_generate_text_llm_result  \
# 0  {"Dep_ID":10000001,"country":"United States","...
# 1  {"Dep_ID":10000002,"country":"United States","...
# 2  {"Dep_ID":10000003,"country":"United States","...
# 3  {"Dep_ID":10000004,"country":"United States","...
# 4  {"Dep_ID":10000005,"country":"United States","...
# 5  {"Dep_ID":10000006,"country":"United States","...
# 6  {"Dep_ID":10000007,"country":"United States","...
# 7  {"Dep_ID":10000008,"country":"United States","...
# 8  {"Dep_ID":10000009,"country":"United States","...
# 9  {"Dep_ID":10000010,"country":"United States","...
#
#   ml_generate_text_rai_result ml_generate_text_status  \
# 0                        None
# 1                        None
# 2                        None
# 3                        None
# 4                        None
# 5                        None
# 6                        None
# 7                        None
# 8                        None
# 9                        None
#
#                                               prompt
# 0  Suggest a county for each site. Return the out...
# 1  Suggest a county for each site. Return the out...
# 2  Suggest a county for each site. Return the out...
# 3  Suggest a county for each site. Return the out...
# 4  Suggest a county for each site. Return the out...
# 5  Suggest a county for each site. Return the out...
# 6  Suggest a county for each site. Return the out...
# 7  Suggest a county for each site. Return the out...
# 8  Suggest a county for each site. Return the out...
# 9  Suggest a county for each site. Return the out...

# %% [markdown]
# #### Tweak the prompt and save the output
# ##### [More details](https://cloud.google.com/bigquery/docs/generate-text#generate_text_from_text_data_by_using_a_prompt_from_a_query) on `ML.generate_text` parameters

# %%
# %%bigquery
# declare prompt_query STRING default "Suggest a county for each dep_id. Return the output as json, include the Dep_ID and county in the output";
# create or replace table retails_stg_ai.county_predictions_raw_10 as
#   select *
#   from ML.generate_text(
#     model remote_models.gemini_pro,
#     (
#       select concat(prompt_query, to_json_string(json_object("Dep_ID", Dep_ID, "site_name", site_name, "latitude", latitude,
#                     "longitude", longitude, "region", region, "country", country, "state", state))) as prompt
#       from retails_stg.Mrds
#       order by Dep_ID
#       limit 10
#     ),
#     struct(0 as temperature, 8192 as max_output_tokens, 0.0 as top_p, 1 as top_k, TRUE as flatten_json_output)
#   );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select ml_generate_text_llm_result, prompt
# from retails_stg_ai.county_predictions_raw_10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          ml_generate_text_llm_result  \
# 0  ```json\n{\n  "Dep_ID": 10000002,\n  "county":...
# 1  ```json\n{\n  "Dep_ID": 10000006,\n  "county":...
# 2  ```json\n{\n  "Dep_ID": 10000004,\n  "county":...
# 3  ```json\n{\n  "Dep_ID": 10000001,\n  "county":...
# 4  {"Dep_ID":10000003,"county":"Fairbanks North S...
# 5  {"Dep_ID":10000007,"country":"United States","...
# 6  {"Dep_ID":10000009,"country":"United States","...
# 7  {"Dep_ID":10000008,"county":"Aleutians East Bo...
# 8  {"Dep_ID":10000005,"county":"Matanuska-Susitna...
# 9  {"Dep_ID":10000010,"country":"United States","...
#
#                                               prompt
# 0  Suggest a county for each dep_id. Return the o...
# 1  Suggest a county for each dep_id. Return the o...
# 2  Suggest a county for each dep_id. Return the o...
# 3  Suggest a county for each dep_id. Return the o...
# 4  Suggest a county for each dep_id. Return the o...
# 5  Suggest a county for each dep_id. Return the o...
# 6  Suggest a county for each dep_id. Return the o...
# 7  Suggest a county for each dep_id. Return the o...
# 8  Suggest a county for each dep_id. Return the o...
# 9  Suggest a county for each dep_id. Return the o...

# %% [markdown]
# #### Format the output to proper json

# %%
# %%bigquery
# select ml_generate_text_llm_result, trim(replace(replace(replace(ml_generate_text_llm_result, '```json', ''), '```', ''), '\n', '')) as formated_result
# from retails_stg_ai.county_predictions_raw_10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          ml_generate_text_llm_result  \
# 0  ```json\n{\n  "Dep_ID": 10000002,\n  "county":...
# 1  ```json\n{\n  "Dep_ID": 10000006,\n  "county":...
# 2  ```json\n{\n  "Dep_ID": 10000004,\n  "county":...
# 3  ```json\n{\n  "Dep_ID": 10000001,\n  "county":...
# 4  {"Dep_ID":10000003,"county":"Fairbanks North S...
# 5  {"Dep_ID":10000007,"country":"United States","...
# 6  {"Dep_ID":10000009,"country":"United States","...
# 7  {"Dep_ID":10000008,"county":"Aleutians East Bo...
# 8  {"Dep_ID":10000005,"county":"Matanuska-Susitna...
# 9  {"Dep_ID":10000010,"country":"United States","...
#
#                                      formated_result
# 0     {  "Dep_ID": 10000002,  "county": "Anchorage"}
# 1  {  "Dep_ID": 10000006,  "county": "Prince of W...
# 2          {  "Dep_ID": 10000004,  "county": "Nome"}
# 3     {  "Dep_ID": 10000001,  "county": "Anchorage"}
# 4  {"Dep_ID":10000003,"county":"Fairbanks North S...
# 5  {"Dep_ID":10000007,"country":"United States","...
# 6  {"Dep_ID":10000009,"country":"United States","...
# 7  {"Dep_ID":10000008,"county":"Aleutians East Bo...
# 8  {"Dep_ID":10000005,"county":"Matanuska-Susitna...
# 9  {"Dep_ID":10000010,"country":"United States","...

# %%
# %%bigquery
# create or replace table retails_stg_ai.county_predictions_formatted_10 as
#   select trim(replace(replace(replace(ml_generate_text_llm_result, '```json', ''), '```', ''), '\n', '')) as ml_generate_text_llm_result
#   from retails_stg_ai.county_predictions_raw_10
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select json_value(ml_generate_text_llm_result, '$.Dep_ID') as Dep_ID,
#   json_value(ml_generate_text_llm_result, '$.county') as county
# from retails_stg_ai.county_predictions_formatted_10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      Dep_ID                           county
# 0  10000007                   Haines Borough
# 1  10000010                             None
# 2  10000002                        Anchorage
# 3  10000004                             Nome
# 4  10000009                             None
# 5  10000005        Matanuska-Susitna Borough
# 6  10000003     Fairbanks North Star Borough
# 7  10000001                        Anchorage
# 8  10000006  Prince of Wales-Outer Ketchikan
# 9  10000008           Aleutians East Borough

# %% [markdown]
# #### Add the county field to the Mrds table

# %%
# %%bigquery
# alter table retails_stg.Mrds add column county_predictions string;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Update the Mrds records with the predicted county

# %%
# %%bigquery
# update retails_stg.Mrds set county_predictions =
#   (select json_value(ml_generate_text_llm_result, '$.county')
#    from retails_stg_ai.county_predictions_formatted_10
#    where Dep_ID = cast(json_value(ml_generate_text_llm_result, '$.Dep_ID') as int64))
# where 1=1
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Inspect the output

# %%
# %%bigquery
# select * except(com_type, commod1, commod2, commod3, data_source, load_time)
# from retails_stg.Mrds
# where county_predictions is not null
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#         Dep_ID                                                url mrds_id  \
# 0     10307293  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 1     10307504  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 2     10307020  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 3     10305981  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 4     10400891  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# ...        ...                                                ...     ...
# 6909  10161241  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 6910  10258319  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 6911  10282564  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 6912  10186027  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 6913  10185293  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
#
#           mas_id                              site_name  latitude  longitude  \
# 0           None            Unnamed (upper Ophir Creek)  65.04933 -163.69331
# 1           None  Unnamed (east of Sugar Loaf Mountain)  63.78961 -148.79286
# 2           None                         St. Pierre Pit  43.36227  -72.32379
# 3           None                           Mammoth Mine  34.31123  -83.81660
# 4           None                    Unknown Borrow Pits  41.77000 -107.47300
# ...          ...                                    ...       ...        ...
# 6909  0021110094                             Pipe Dream  58.86222 -136.86882
# 6910  0021110096          Helicopter Pilot's Molybdenum  58.71361 -137.27852
# 6911  0021110107              Dagelet River Beach Sands  58.51750 -137.40631
# 6912  0021110110               Kaknau Creek Beach Sands  58.40141 -137.08070
# 6913  0021110111                Palma River Beach Sands  58.40661 -136.98269
#
#      region        country          state    county  \
# 0        NA  United States         Alaska      None
# 1        NA  United States         Alaska      None
# 2        NA  United States  New Hampshire  Sullivan
# 3        NA  United States        Georgia      Hall
# 4        NA  United States        Wyoming    Carbon
# ...     ...            ...            ...       ...
# 6909     NA  United States         Alaska      None
# 6910     NA  United States         Alaska      None
# 6911     NA  United States         Alaska      None
# 6912     NA  United States         Alaska      None
# 6913     NA  United States         Alaska      None
#
#                                county_predictions
# 0                       Yukon-Koyukuk Census Area
# 1                                  Denali Borough
# 2                                  Grafton County
# 3                                   Fulton County
# 4                               Sweetwater County
# ...                                           ...
# 6909                         Fairbanks North Star
# 6910                               Haines Borough
# 6911  Prince of Wales-Outer Ketchikan Census Area
# 6912                               Haines Borough
# 6913                               Haines Borough
#
# [6914 rows x 12 columns]

# %% [markdown]
# #### Apply at larger scale

# %% [markdown]
# ###### Create a smaller Mrds table with 10K records in order to finish within 30 minutes

# %%
# %%bigquery
# create or replace table retails_stg.Mrds_10k as
#   select *
#   from retails_stg.Mrds
#   where Dep_ID is not null
#   and site_name is not null
#   and latitude is not null
#   and longitude is not null
#   and region is not null
#   and state is not null
#   limit 10000
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select count(*)
# from retails_stg.Mrds_10k
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      f0_
# 0  10000

# %%
# %%bigquery
# declare prompt_query STRING default "Suggest a county for each dep_id. Return the output as json, include the Dep_ID and county in the output";
# create or replace table retails_stg_ai.county_predictions_raw_10k as
#   select *
#   from ML.generate_text(
#     model remote_models.gemini_pro,
#     (
#       select concat(prompt_query, to_json_string(json_object("Dep_ID", Dep_ID, "site_name", site_name, "latitude", latitude,
#                     "longitude", longitude, "region", region, "country", country, "state", state))) as prompt
#       from retails_stg.Mrds_10k
#     ),
#     struct(0 as temperature, 8192 as max_output_tokens, 0.0 as top_p, 1 as top_k, TRUE as flatten_json_output)
#   );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select creation_time, end_time, query
# from `region-us`.INFORMATION_SCHEMA.JOBS
# where job_id = '90f3a532-3af8-4a2d-aba9-962fc313ef6a'
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                      creation_time                         end_time  \
# 0 2024-04-10 18:41:36.410000+00:00 2024-04-10 19:25:21.814000+00:00
#
#                                                query
# 0  declare prompt_query STRING default "Suggest a...

# %%
# %%bigquery
# create or replace table retails_stg_ai.county_predictions_formatted_10k as
#   select trim(replace(replace(replace(ml_generate_text_llm_result, '```json', ''), '```', ''), '\n', '')) as ml_generate_text_llm_result
#   from retails_stg_ai.county_predictions_raw_10k
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select count(*) as county_count
# from retails_stg_ai.county_predictions_formatted_10k
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    county_count
# 0         10000

# %%
# %%bigquery
# select json_value(ml_generate_text_llm_result, '$.Dep_ID') as Dep_ID,
#   json_value(ml_generate_text_llm_result, '$.county') as county_predictions
# from retails_stg_ai.county_predictions_formatted_10k
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#         Dep_ID county_predictions
# 0         None               None
# 1         None               None
# 2         None               None
# 3         None               None
# 4         None               None
# ...        ...                ...
# 9995  10257920     Calhoun County
# 9996  10258319     Haines Borough
# 9997  10306937      Warren County
# 9998  10306989        Clay County
# 9999  10307994               None
#
# [10000 rows x 2 columns]

# %% [markdown]
# Add the county field to the Mrds table

# %%
# %%bigquery
# alter table retails_stg.Mrds add column county_predictions string;
# Out:
# Executing query with job ID: 0a7788e4-faae-4a6c-83d9-a2d8aac53145
# Query executing: 0.52s
# ERROR:
#  400 Column already exists: county_predictions at [1:41]
#
# Location: US
# Job ID: 0a7788e4-faae-4a6c-83d9-a2d8aac53145

# %% [markdown]
# Update the Mrds records with the predicted county

# %%
# %%bigquery
# update retails_stg.Mrds set county_predictions =
#   (select json_value(ml_generate_text_llm_result, '$.county')
#    from retails_stg_ai.county_predictions_formatted_10k
#    where Dep_ID = cast(json_value(ml_generate_text_llm_result, '$.Dep_ID') as int64))
# where 1=1
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select *
# from retails_stg.Mrds
# where county_predictions is not null
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#         Dep_ID                                                url mrds_id  \
# 0     10308191  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 1     10310446  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 2     10307204  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 3     10307081  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 4     10400525  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# ...        ...                                                ...     ...
# 6909  10161241  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 6910  10258319  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 6911  10282564  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 6912  10186027  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 6913  10185293  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
#
#           mas_id                       site_name  latitude  longitude region  \
# 0           None  Unnamed (west of Lupine River)  68.79977 -148.35348     NA
# 1           None                     Rat Deposit  39.92381 -115.54700     NA
# 2           None        North Pacolet River Mine  35.16641  -82.02874     NA
# 3           None                    Masters Kiln  34.43452  -82.17765     NA
# 4           None                    Boden Placer  41.41816 -106.45450     NA
# ...          ...                             ...       ...        ...    ...
# 6909  0021110094                      Pipe Dream  58.86222 -136.86882     NA
# 6910  0021110096   Helicopter Pilot's Molybdenum  58.71361 -137.27852     NA
# 6911  0021110107       Dagelet River Beach Sands  58.51750 -137.40631     NA
# 6912  0021110110        Kaknau Creek Beach Sands  58.40141 -137.08070     NA
# 6913  0021110111         Palma River Beach Sands  58.40661 -136.98269     NA
#
#             country           state       county com_type  \
# 0     United States          Alaska         None     None
# 1     United States          Nevada   White Pine        M
# 2     United States  South Carolina  Spartanburg        N
# 3     United States  South Carolina      Laurens        N
# 4     United States         Wyoming       Carbon        N
# ...             ...             ...          ...      ...
# 6909  United States          Alaska         None        M
# 6910  United States          Alaska         None        M
# 6911  United States          Alaska         None        M
# 6912  United States          Alaska         None        M
# 6913  United States          Alaska         None        M
#
#                     commod1 commod2               commod3 data_source  \
# 0     Phosphorus-Phosphates    None                  None        usgs
# 1                      Gold    None               Mercury        usgs
# 2                      Sand    None                  None        usgs
# 3        Limestone, General    None                  None        usgs
# 4                   Diamond    None                  None        usgs
# ...                     ...     ...                   ...         ...
# 6909                   Gold    None                  None        usgs
# 6910             Molybdenum    None                  None        usgs
# 6911         Gold, Titanium    None             Iron, PGE        usgs
# 6912               Titanium    None  Gold, Iron, Platinum        usgs
# 6913               Titanium    None            Gold, Iron        usgs
#
#                             load_time  \
# 0    2024-02-02 22:02:24.030800+00:00
# 1    2024-02-02 22:02:24.030800+00:00
# 2    2024-02-02 22:02:24.030800+00:00
# 3    2024-02-02 22:02:24.030800+00:00
# 4    2024-02-02 22:02:24.030800+00:00
# ...                               ...
# 6909 2024-02-02 22:02:24.030800+00:00
# 6910 2024-02-02 22:02:24.030800+00:00
# 6911 2024-02-02 22:02:24.030800+00:00
# 6912 2024-02-02 22:02:24.030800+00:00
# 6913 2024-02-02 22:02:24.030800+00:00
#
#                                county_predictions
# 0                    Fairbanks North Star Borough
# 1                                     Elko County
# 2                                     Spartanburg
# 3                                      Greenville
# 4                                   Albany County
# ...                                           ...
# 6909                         Fairbanks North Star
# 6910                               Haines Borough
# 6911  Prince of Wales-Outer Ketchikan Census Area
# 6912                               Haines Borough
# 6913                               Haines Borough
#
# [6914 rows x 18 columns]

# %%
# %%bigquery
# select count(*) as county_predictions_count
# from retails_stg.Mrds
# where county_predictions is not null
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    county_predictions_count
# 0                      6914

# %%
# %%bigquery
# select state, county_predictions, count(*) as count
# from retails_stg.Mrds
# where county_predictions is not null
# group by state, county_predictions
# order by count(*) desc
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#        state    county_predictions  count
# 0     Alaska  Fairbanks North Star   1030
# 1    Alabama      Jefferson County   1009
# 2    Alabama     Montgomery County    502
# 3     Alaska             Anchorage    294
# 4    Wyoming     Sweetwater County    268
# ..       ...                   ...    ...
# 485   Alaska             Frederick      1
# 486   Alaska              Bay City      1
# 487   Alaska    Hale-Peel-Lyngholm      1
# 488   Alaska             Josephine      1
# 489   Alaska               Wautosh      1
#
# [490 rows x 3 columns]

# %%
# %%bigquery
# update retails_stg.Mrds
#   set data_source = 'usgs' where county_predictions is not null
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Part 2: Find the mineral types of a mineral site

# %% [markdown]
# #### Experiment with prompt

# %%
# %%bigquery
# select *
# from retails_stg.Mrds_10k
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#         Dep_ID                                                url mrds_id  \
# 0     10307950  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 1     10308100  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 2     10307951  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 3     10307952  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 4     10308079  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# ...        ...                                                ...     ...
# 9995  10307221  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 9996  10400337  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 9997  10400325  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 9998  10400463  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 9999  10400502  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
#
#      mas_id                                          site_name  latitude  \
# 0      None                      Unnamed (near Ahlfield Creek)  64.80379
# 1      None              Unnamed (southwest of Portage Valley)  55.69924
# 2      None  Unnamed (on ridge between Ahlfield and Christi...  64.80729
# 3      None                                       Little Gulch  64.80909
# 4      None        Unnamed (south end of Inner IIiasik Island)  55.03921
# ...     ...                                                ...       ...
# 9995   None              Illinois - Kentucky Fluorite District  37.41673
# 9996   None                                     Viburnum Trend  37.53837
# 9997   None                      Olive Hill Fire Clay District  38.31667
# 9998   None      Central Florida Land Pebble Phosphate Deposit  27.66000
# 9999   None                 Florida Hardrock Phosphate Deposit  29.70000
#
#       longitude region        country               state  \
# 0    -165.17020     NA  United States              Alaska
# 1    -160.60244     NA  United States              Alaska
# 2    -165.18610     NA  United States              Alaska
# 3    -165.23120     NA  United States              Alaska
# 4    -161.93942     NA  United States              Alaska
# ...         ...    ...            ...                 ...
# 9995  -88.35004     NA  United States  Kentucky, Illinois
# 9996  -91.12903     NA  United States            Missouri
# 9997  -83.03333     NA  United States            Kentucky
# 9998  -82.04000     NA  United States             Florida
# 9999  -83.20000     NA  United States             Florida
#
#                                                  county com_type  \
# 0                                                  None     None
# 1                                                  None     None
# 2                                                  None     None
# 3                                                  None     None
# 4                                                  None     None
# ...                                                 ...      ...
# 9995               Livingston, Pope, Hardin, Crittenden        B
# 9996      Washington, Crawford, Reynolds, Shannon, Iron     None
# 9997     Lewis, Greenup, Rowan, Elliott, Morgan, Carter        N
# 9998  Polk, Hillsborough, Manatee, Hardee, DeSoto, S...     None
# 9999  Dixie, Lafayette, Gilchrist, Levy, Alachua, Ma...     None
#
#                             commod1                 commod2  \
# 0                              None                    None
# 1                              None                    None
# 2                              None                    None
# 3                              None                    None
# 4                              None                    None
# ...                             ...                     ...
# 9995  Lead, Zinc, Fluorine-Fluorite         Silver, Cadmium
# 9996                     Lead, Zinc  Cobalt, Silver, Copper
# 9997         Fire Clay (Refractory)                    None
# 9998          Phosphorus-Phosphates                    None
# 9999          Phosphorus-Phosphates                    None
#
#                          commod3 data_source                        load_time  \
# 0                           None        usgs 2024-02-02 22:02:24.030800+00:00
# 1                           None        usgs 2024-02-02 22:02:24.030800+00:00
# 2                           None        usgs 2024-02-02 22:02:24.030800+00:00
# 3                           None        usgs 2024-02-02 22:02:24.030800+00:00
# 4                           None        usgs 2024-02-02 22:02:24.030800+00:00
# ...                          ...         ...                              ...
# 9995                        None        usgs 2024-02-02 22:02:24.030800+00:00
# 9996             Cadmium, Nickel        usgs 2024-02-02 22:02:24.030800+00:00
# 9997                        None        usgs 2024-02-02 22:02:24.030800+00:00
# 9998  Uranium, Fluorine-Fluorite        usgs 2024-02-02 22:02:24.030800+00:00
# 9999                        None        usgs 2024-02-02 22:02:24.030800+00:00
#
#      county_predictions
# 0                  None
# 1                  None
# 2                  None
# 3                  None
# 4                  None
# ...                 ...
# 9995               None
# 9996               None
# 9997               None
# 9998               None
# 9999               None
#
# [10000 rows x 18 columns]

# %%
# %%bigquery
# declare prompt_query STRING default "Suggest a mineral type of each dep_id. Choose between silicates, sulfides, or carbonates. Return the output as json, include the Dep_ID and the mineral_type in the output as well";
# select *
# from ML.generate_text(
#   model remote_models.gemini_pro,
#   (
#       select concat(prompt_query, to_json_string(json_object("Dep_ID", Dep_ID, "com_type", com_type,
#                     "commod1", commod1, "commod2", commod1, "commod3", commod3))) as prompt
#     from retails_stg.Mrds_10k
#     order by site_name
#     limit 10
#   ),
#   struct(0 as temperature, 8192 as max_output_tokens, 0.0 as top_p, 1 as top_k, TRUE as flatten_json_output)
# );
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          ml_generate_text_llm_result  \
# 0  {"Dep_ID":10282235,"com_type":"M","commod1":"I...
# 1      {"Dep_ID":10112331,"mineral_type":"sulfides"}
# 2  ```json\n{"Dep_ID":10184883,"mineral_type":"si...
# 3  {"Dep_ID":10257940,"com_type":"M","commod1":"G...
# 4  {"Dep_ID":10306857,"com_type":"M","commod1":"L...
# 5  {"Dep_ID":10234107,"com_type":"N","commod1":"S...
# 6  {"Dep_ID":10282682,"com_type":"M","commod1":"G...
# 7  {"Dep_ID":10132620,"com_type":"E","commod1":"U...
# 8      {"Dep_ID":10233783,"mineral_type":"sulfides"}
# 9  {"Dep_ID":10112394,"com_type":"N","commod1":"S...
#
#   ml_generate_text_rai_result ml_generate_text_status  \
# 0                        None
# 1                        None
# 2                        None
# 3                        None
# 4                        None
# 5                        None
# 6                        None
# 7                        None
# 8                        None
# 9                        None
#
#                                               prompt
# 0  Suggest a mineral type of each dep_id. Choose ...
# 1  Suggest a mineral type of each dep_id. Choose ...
# 2  Suggest a mineral type of each dep_id. Choose ...
# 3  Suggest a mineral type of each dep_id. Choose ...
# 4  Suggest a mineral type of each dep_id. Choose ...
# 5  Suggest a mineral type of each dep_id. Choose ...
# 6  Suggest a mineral type of each dep_id. Choose ...
# 7  Suggest a mineral type of each dep_id. Choose ...
# 8  Suggest a mineral type of each dep_id. Choose ...
# 9  Suggest a mineral type of each dep_id. Choose ...

# %%
# %%bigquery
# declare prompt_query STRING default "Suggest a mineral type of each dep_id. Choose between silicates, sulfides, or carbonates. Return the output as json, include the Dep_ID and the mineral_type in the output as well";
# create or replace table retails_stg_ai.type_predictions_raw_10 as
#   select *
#   from ML.generate_text(
#     model remote_models.gemini_pro,
#     (
#       select concat(prompt_query, to_json_string(json_object("Dep_ID", Dep_ID, "com_type", com_type,
#                     "commod1", commod1, "commod2", commod1, "commod3", commod3))) as prompt
#     from retails_stg.Mrds_10k
#     order by site_name
#     limit 10
#     ),
#     struct(0 as temperature, 8192 as max_output_tokens, 0.0 as top_p, 1 as top_k, TRUE as flatten_json_output)
#   );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select ml_generate_text_llm_result, prompt
# from retails_stg_ai.type_predictions_raw_10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          ml_generate_text_llm_result  \
# 0      {"Dep_ID":10112331,"mineral_type":"sulfides"}
# 1  {"Dep_ID":10282235,"com_type":"M","commod1":"I...
# 2  {"Dep_ID":10306857,"com_type":"M","commod1":"L...
# 3  ```json\n{"Dep_ID":10184883,"mineral_type":"si...
# 4  {"Dep_ID":10282682,"com_type":"M","commod1":"G...
# 5  {"Dep_ID":10257940,"com_type":"M","commod1":"G...
# 6  {"Dep_ID":10132620,"com_type":"E","commod1":"U...
# 7  {"Dep_ID":10234107,"com_type":"N","commod1":"S...
# 8  {"Dep_ID":10112394,"com_type":"N","commod1":"S...
# 9      {"Dep_ID":10233783,"mineral_type":"sulfides"}
#
#                                               prompt
# 0  Suggest a mineral type of each dep_id. Choose ...
# 1  Suggest a mineral type of each dep_id. Choose ...
# 2  Suggest a mineral type of each dep_id. Choose ...
# 3  Suggest a mineral type of each dep_id. Choose ...
# 4  Suggest a mineral type of each dep_id. Choose ...
# 5  Suggest a mineral type of each dep_id. Choose ...
# 6  Suggest a mineral type of each dep_id. Choose ...
# 7  Suggest a mineral type of each dep_id. Choose ...
# 8  Suggest a mineral type of each dep_id. Choose ...
# 9  Suggest a mineral type of each dep_id. Choose ...

# %%
# %%bigquery
# create or replace table retails_stg_ai.type_predictions_formatted_10 as
#   select trim(replace(replace(replace(ml_generate_text_llm_result, '```json', ''), '```', ''), '\n', '')) as ml_generate_text_llm_result
#   from retails_stg_ai.type_predictions_raw_10
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select * from retails_stg_ai.type_predictions_formatted_10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          ml_generate_text_llm_result
# 0  {"Dep_ID":10282682,"com_type":"M","commod1":"G...
# 1  {"Dep_ID":10306857,"com_type":"M","commod1":"L...
# 2  {"Dep_ID":10132620,"com_type":"E","commod1":"U...
# 3  {"Dep_ID":10112394,"com_type":"N","commod1":"S...
# 4      {"Dep_ID":10233783,"mineral_type":"sulfides"}
# 5  {"Dep_ID":10234107,"com_type":"N","commod1":"S...
# 6  {"Dep_ID":10282235,"com_type":"M","commod1":"I...
# 7      {"Dep_ID":10112331,"mineral_type":"sulfides"}
# 8  {"Dep_ID":10257940,"com_type":"M","commod1":"G...
# 9     {"Dep_ID":10184883,"mineral_type":"silicates"}

# %%
# %%bigquery
# alter table retails_stg.Mrds add column mineral_type string;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# update retails_stg.Mrds set mineral_type =
#   (select json_value(ml_generate_text_llm_result, '$.mineral_type')
#    from retails_stg_ai.type_predictions_formatted_10
#    where Dep_ID = cast(json_value(ml_generate_text_llm_result, '$.Dep_ID') as int64))
# where 1=1;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select * except(latitude, longitude, region, country, state, county, data_source, load_time)
# from retails_stg.Mrds
# where mineral_type is not null
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      Dep_ID                                                url mrds_id  \
# 0  10306857  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 1  10132620  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 2  10184883  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 3  10282235  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 4  10112331  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 5  10257940  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 6  10233783  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 7  10282682  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 8  10112394  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 9  10234107  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
#
#        mas_id                         site_name com_type  \
# 0        None                1580 Brook Prospet        M
# 1   560070634                           2 D Pit        E
# 2  0010250006                                02        N
# 3  0010719003  (Facility) Bridgeport Jv Smelter        M
# 4  0011259902    (Facility) Tuscaloosa Refinery        N
# 5  0020500371                          101 Mine        M
# 6  0020860176       2nd Adit East of Cliff Mine        M
# 7  0020860177       1st Adit East of Cliff Mine        M
# 8  0020960086                    3 Mile Bay Pit        N
# 9  0020960090                    17 Mile Quarry        N
#
#                          commod1 commod2 commod3 county_predictions  \
# 0                        Lithium    None    None               None
# 1                        Uranium    None    None      Albany County
# 2  Sand and Gravel, Construction    None    None               None
# 3                   Iron, Silica    None    None               None
# 4                         Sulfur    None    None               None
# 5                           Gold    None    None               None
# 6                           Gold    None  Silver     Valdez-Cordova
# 7                           Gold    None  Silver     Valdez-Cordova
# 8  Sand and Gravel, Construction    None    None     Denali Borough
# 9                          Stone    None    None               None
#
#   mineral_type
# 0    silicates
# 1    silicates
# 2    silicates
# 3    silicates
# 4     sulfides
# 5     sulfides
# 6     sulfides
# 7     sulfides
# 8    silicates
# 9    silicates

# %% [markdown]
# #### Apply at larger scale

# %%
# %%bigquery
# declare prompt_query STRING default "Suggest a mineral type of each dep_id. Choose between silicates, sulfides, or carbonates. Return the output as json, include the Dep_ID and the mineral_type in the output as well";
# create or replace table retails_stg_ai.type_predictions_raw_10k as
#   select *
#   from ML.generate_text(
#     model remote_models.gemini_pro,
#     (
#         select concat(prompt_query, to_json_string(json_object("Dep_ID", Dep_ID, "com_type", com_type,
#                       "commod1", commod1, "commod2", commod1, "commod3", commod3))) as prompt
#       from retails_stg.Mrds_10k
#       order by Dep_ID
#     ),
#     struct(0 as temperature, 8192 as max_output_tokens, 0.0 as top_p, 1 as top_k, TRUE as flatten_json_output)
#   );
# Out:
# Executing query with job ID: 405708fc-b807-4842-85d8-3dac263c39c1
# Query executing: 3052.44s

# %%
# %%bigquery
# select ml_generate_text_llm_result, prompt
# from retails_stg_ai.type_predictions_raw_10k
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                             ml_generate_text_llm_result  \
# 0        {"Dep_ID":10111672,"mineral_type":"silicates"}
# 1     {"Dep_ID":10111768,"com_type":"M","commod1":"G...
# 2     ```json\n{\n  "Dep_ID": 10111798,\n  "mineral_...
# 3     {"Dep_ID":10111808,"com_type":"M","commod1":"I...
# 4     ```json\n{\n  "Dep_ID": 10111844,\n  "mineral_...
# ...                                                 ...
# 9995                                               None
# 9996                                               None
# 9997                                               None
# 9998                                               None
# 9999                                               None
#
#                                                  prompt
# 0     Suggest a mineral type of each dep_id. Choose ...
# 1     Suggest a mineral type of each dep_id. Choose ...
# 2     Suggest a mineral type of each dep_id. Choose ...
# 3     Suggest a mineral type of each dep_id. Choose ...
# 4     Suggest a mineral type of each dep_id. Choose ...
# ...                                                 ...
# 9995  Suggest a mineral type of each dep_id. Choose ...
# 9996  Suggest a mineral type of each dep_id. Choose ...
# 9997  Suggest a mineral type of each dep_id. Choose ...
# 9998  Suggest a mineral type of each dep_id. Choose ...
# 9999  Suggest a mineral type of each dep_id. Choose ...
#
# [10000 rows x 2 columns]

# %%
# %%bigquery
# select trim(replace(replace(replace(ml_generate_text_llm_result, '```json', ''), '```', ''), '\n', '')) as ml_generate_text_llm_result
# from retails_stg_ai.type_predictions_raw_10k
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                             ml_generate_text_llm_result
# 0        {"Dep_ID":10111672,"mineral_type":"silicates"}
# 1     {"Dep_ID":10111768,"com_type":"M","commod1":"G...
# 2     {  "Dep_ID": 10111798,  "mineral_type": "silic...
# 3     {"Dep_ID":10111808,"com_type":"M","commod1":"I...
# 4     {  "Dep_ID": 10111844,  "mineral_type": "silic...
# ...                                                 ...
# 9995                                               None
# 9996                                               None
# 9997                                               None
# 9998                                               None
# 9999                                               None
#
# [10000 rows x 1 columns]

# %%
# %%bigquery
# create or replace table retails_stg_ai.type_predictions_formatted_10k as
#   select trim(replace(replace(replace(ml_generate_text_llm_result, '```json', ''), '```', ''), '\n', '')) as ml_generate_text_llm_result
#   from retails_stg_ai.type_predictions_raw_10k
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select count(*) as mineraltype_count
# from retails_stg_ai.type_predictions_formatted_10k
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    mineraltype_count
# 0              10000

# %%
# %%bigquery
# select *
# from retails_stg_ai.type_predictions_formatted_10k
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                             ml_generate_text_llm_result
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 9995  {"Dep_ID":10136855,"com_type":"B","commod1":"G...
# 9996  {"Dep_ID":10136550,"com_type":"B","commod1":"B...
# 9997  {"Dep_ID":10310452,"com_type":"B","commod1":"G...
# 9998  {"Dep_ID":10306815,"com_type":"B","commod1":"S...
# 9999  {"Dep_ID":10308735,"com_type":"B","commod1":"S...
#
# [10000 rows x 1 columns]

# %%
# %%bigquery
# alter table retails_stg.Mrds add column type string;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# update retails_stg.Mrds set mineral_type =
#   (select json_value(ml_generate_text_llm_result, '$.mineral_type')
#    from retails_stg_ai.type_predictions_formatted_10k
#    where Dep_ID = cast(json_value(ml_generate_text_llm_result, '$.Dep_ID')as int64))
# where 1=1
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select * except(latitude, longitude, region, country, state, county, data_source, load_time,type)
# from retails_stg.Mrds
# where mineral_type is not null
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#         Dep_ID                                                url mrds_id  \
# 0     10308679  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 1     10308595  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 2     10308704  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 3     10306970  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 4     10308130  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# ...        ...                                                ...     ...
# 9838  10185523  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 9839  10282564  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 9840  10185682  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 9841  10186027  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
# 9842  10185293  https://mrdata.usgs.gov/mrds/show-mrds.php?dep...    None
#
#           mas_id                       site_name com_type  \
# 0           None                     Butte Creek        M
# 1           None                         Caribou        M
# 2           None                       Red Creek        M
# 3           None   Southern Belt-Sand and Gravel        N
# 4           None  Unnamed (south of Zachary Bay)     None
# ...          ...                             ...      ...
# 9838  0021110106         Topsy Creek Beach Sands        M
# 9839  0021110107       Dagelet River Beach Sands        M
# 9840  0021110109       La Perouse-Icy Beach Sand        M
# 9841  0021110110        Kaknau Creek Beach Sands        M
# 9842  0021110111         Palma River Beach Sands        M
#
#                             commod1              commod2  \
# 0                              Gold                 None
# 1                              Gold                 None
# 2                              Gold  Zinc, Lead, Mercury
# 3     Sand and Gravel, Construction                 None
# 4                      Copper, Gold           Molybdenum
# ...                             ...                  ...
# 9838                           Gold                 None
# 9839                 Gold, Titanium                 None
# 9840                       Titanium                 None
# 9841                       Titanium                 None
# 9842                       Titanium                 None
#
#                        commod3                           county_predictions  \
# 0                         None                                         None
# 1                         None                                         None
# 2                         None                                         None
# 3                         None                                         None
# 4                         None                       Aleutians East Borough
# ...                        ...                                          ...
# 9838  Iron, Platinum, Titanium                                         None
# 9839                 Iron, PGE  Prince of Wales-Outer Ketchikan Census Area
# 9840      Gold, Iron, Platinum                                         None
# 9841      Gold, Iron, Platinum                               Haines Borough
# 9842                Gold, Iron                               Haines Borough
#
#      mineral_type
# 0        sulfides
# 1        sulfides
# 2        sulfides
# 3       silicates
# 4        sulfides
# ...           ...
# 9838     Sulfides
# 9839     Sulfides
# 9840    silicates
# 9841    silicates
# 9842    silicates
#
# [9843 rows x 11 columns]

# %%
# %%bigquery
# select mineral_type, count(*) as count
# from retails_stg.Mrds
# where mineral_type is not null
# group by  mineral_type
# order by count(*) desc
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    mineral_type  count
# 0     silicates   4845
# 1      sulfides   4387
# 2    carbonates    254
# 3      Sulfides    245
# 4    Carbonates     51
# 5    Phosphates     23
# 6    phosphates     13
# 7      Fluorite     10
# 8   tungstenite      7
# 9      sulfates      6
# 10       oxides      2

# %%
# %%bigquery
# select count(*) as mineraltype_count
# from retails_stg.Mrds
# where mineral_type is not null
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    mineraltype_count
# 0               9843

# %%
# %%bigquery
# update retails_stg.Mrds
#   set data_source = 'usgs' where mineral_type is not null
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Part 3: Find what holiday a transaction occured in

# %% [markdown]
# ####Experiment with prompt

# %%
# %%bigquery
# select * except (Day, Month, Year, store_nbr, family, sales_amount, data_source, load_time)
# from retails_stg.Transactions
# where date is not null
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    Transaction_ID        date  on_promotion holiday
# 0             735  2013-01-01         False    None
# 1             636  2013-01-01         False    None
# 2             372  2013-01-01         False    None
# 3             273  2013-01-01         False    None
# 4             801  2013-01-01         False    None

# %%
# %%bigquery
# declare prompt_query STRING default "Suggest a holiday for each transaction. Return the output as json, include the Transaction_ID and holiday in the output";
# select *
# from ML.generate_text(
#   model remote_models.gemini_pro,
#   (
#     select concat(prompt_query, to_json_string(json_object("Transaction_ID", Transaction_ID, "date", date,
#                   "on_promotion", on_promotion))) as prompt
#     from retails_stg.Transactions
#     order by Transaction_ID
#     limit 10
#   ),
#   struct(TRUE as flatten_json_output)
# );
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          ml_generate_text_llm_result  \
# 0  ```json\n{\n  "Transaction_ID": 0,\n  "date": ...
# 1  ```json\n{\n  "Transaction_ID": 1,\n  "date": ...
# 2  ```json\n{\n  "Transaction_ID": 2,\n  "date": ...
# 3  ```json\n{\n  "Transaction_ID": 3,\n  "date": ...
# 4  ```json\n{\n  "Transaction_ID": 4,\n  "date": ...
# 5  ```json\n{\n  "Transaction_ID": 5,\n  "date": ...
# 6  ```json\n{\n  "Transaction_ID": 6,\n  "date": ...
# 7  ```json\n{\n  "Transaction_ID": 7,\n  "date": ...
# 8  ```json\n{\n  "Transaction_ID": 8,\n  "date": ...
# 9  ```json\n{\n  "Transaction_ID": 9,\n  "date": ...
#
#   ml_generate_text_rai_result ml_generate_text_status  \
# 0                        None
# 1                        None
# 2                        None
# 3                        None
# 4                        None
# 5                        None
# 6                        None
# 7                        None
# 8                        None
# 9                        None
#
#                                               prompt
# 0  Suggest a holiday for each transaction. Return...
# 1  Suggest a holiday for each transaction. Return...
# 2  Suggest a holiday for each transaction. Return...
# 3  Suggest a holiday for each transaction. Return...
# 4  Suggest a holiday for each transaction. Return...
# 5  Suggest a holiday for each transaction. Return...
# 6  Suggest a holiday for each transaction. Return...
# 7  Suggest a holiday for each transaction. Return...
# 8  Suggest a holiday for each transaction. Return...
# 9  Suggest a holiday for each transaction. Return...

# %% [markdown]
# ####Tweak the prompt and save the output

# %%
# %%bigquery
# declare prompt_query STRING default "Suggest a holiday for each transaction. Return the output as json, include the Transaction_ID and holiday in the output";
# create or replace table retails_stg_ai.holiday_predictions_raw_10 as
#   select *
#   from ML.generate_text(
#     model remote_models.gemini_pro,
#     (
#     select concat(prompt_query, to_json_string(json_object("Transaction_ID", Transaction_ID, "date", date,
#                   "on_promotion", on_promotion))) as prompt
#     from retails_stg.Transactions
#     order by Transaction_ID
#     limit 10
#     ),
#     struct(0 as temperature, 8192 as max_output_tokens, 0.0 as top_p, 1 as top_k, TRUE as flatten_json_output)
#   );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select ml_generate_text_llm_result, prompt
# from retails_stg_ai.holiday_predictions_raw_10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          ml_generate_text_llm_result  \
# 0  ```json\n{\n  "Transaction_ID": 4,\n  "date": ...
# 1  ```json\n{\n  "Transaction_ID": 3,\n  "date": ...
# 2  ```json\n{\n  "Transaction_ID": 2,\n  "date": ...
# 3  ```json\n{\n  "Transaction_ID": 6,\n  "date": ...
# 4  ```json\n{\n  "Transaction_ID": 1,\n  "date": ...
# 5  ```json\n{\n  "Transaction_ID": 7,\n  "date": ...
# 6  ```json\n{\n  "Transaction_ID": 9,\n  "date": ...
# 7  ```json\n{\n  "Transaction_ID": 5,\n  "date": ...
# 8  ```json\n{\n  "Transaction_ID": 0,\n  "date": ...
# 9  ```json\n{\n  "Transaction_ID": 8,\n  "date": ...
#
#                                               prompt
# 0  Suggest a holiday for each transaction. Return...
# 1  Suggest a holiday for each transaction. Return...
# 2  Suggest a holiday for each transaction. Return...
# 3  Suggest a holiday for each transaction. Return...
# 4  Suggest a holiday for each transaction. Return...
# 5  Suggest a holiday for each transaction. Return...
# 6  Suggest a holiday for each transaction. Return...
# 7  Suggest a holiday for each transaction. Return...
# 8  Suggest a holiday for each transaction. Return...
# 9  Suggest a holiday for each transaction. Return...

# %% [markdown]
# ####Format the output to proper json

# %%
# %%bigquery
# select ml_generate_text_llm_result, trim(replace(replace(replace(ml_generate_text_llm_result, '```json', ''), '```', ''), '\n', '')) as formated_result
# from retails_stg_ai.holiday_predictions_raw_10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          ml_generate_text_llm_result  \
# 0  ```json\n{\n  "Transaction_ID": 4,\n  "date": ...
# 1  ```json\n{\n  "Transaction_ID": 3,\n  "date": ...
# 2  ```json\n{\n  "Transaction_ID": 2,\n  "date": ...
# 3  ```json\n{\n  "Transaction_ID": 6,\n  "date": ...
# 4  ```json\n{\n  "Transaction_ID": 1,\n  "date": ...
# 5  ```json\n{\n  "Transaction_ID": 7,\n  "date": ...
# 6  ```json\n{\n  "Transaction_ID": 9,\n  "date": ...
# 7  ```json\n{\n  "Transaction_ID": 5,\n  "date": ...
# 8  ```json\n{\n  "Transaction_ID": 0,\n  "date": ...
# 9  ```json\n{\n  "Transaction_ID": 8,\n  "date": ...
#
#                                      formated_result
# 0  {  "Transaction_ID": 4,  "date": "2013-01-01",...
# 1  {  "Transaction_ID": 3,  "date": "2013-01-01",...
# 2  {  "Transaction_ID": 2,  "date": "2013-01-01",...
# 3  {  "Transaction_ID": 6,  "date": "2013-01-01",...
# 4  {  "Transaction_ID": 1,  "date": "2013-01-01",...
# 5  {  "Transaction_ID": 7,  "date": "2013-01-01",...
# 6  {  "Transaction_ID": 9,  "date": "2013-01-01",...
# 7  {  "Transaction_ID": 5,  "date": "2013-01-01",...
# 8  {  "Transaction_ID": 0,  "date": "2013-01-01",...
# 9  {  "Transaction_ID": 8,  "date": "2013-01-01",...

# %%
# %%bigquery
# create or replace table retails_stg_ai.holiday_predictions_formatted_10 as
#   select trim(replace(replace(replace(ml_generate_text_llm_result, '```json', ''), '```', ''), '\n', '')) as ml_generate_text_llm_result
#   from retails_stg_ai.holiday_predictions_raw_10
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select json_value(ml_generate_text_llm_result, '$.Transaction_ID') as Transaction_ID,
#   json_value(ml_generate_text_llm_result, '$.holiday') as holiday
# from retails_stg_ai.holiday_predictions_formatted_10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#   Transaction_ID         holiday
# 0              8  New Year's Day
# 1              0  New Year's Day
# 2              2  New Year's Day
# 3              9  New Year's Day
# 4              5  New Year's Day
# 5              3  New Year's Day
# 6              1  New Year's Day
# 7              4  New Year's Day
# 8              7  New Year's Day
# 9              6  New Year's Day

# %% [markdown]
# ####Add the holiday field to the Transaction table

# %%
# %%bigquery
# alter table retails_stg.Transactions add column holiday string;
# Out:
# Executing query with job ID: 6e2212eb-125c-4eae-9f78-ad08986dfee7
# Query executing: 0.41s
# ERROR:
#  400 Column already exists: holiday at [1:49]
#
# Location: US
# Job ID: 6e2212eb-125c-4eae-9f78-ad08986dfee7

# %% [markdown]
# ####Update the Mineral records with the predicted holiday

# %%
# %%bigquery
# update retails_stg.Transactions set holiday =
#   (select json_value(ml_generate_text_llm_result, '$.holiday')
#    from retails_stg_ai.holiday_predictions_formatted_10
#    where Transaction_ID = cast(json_value(ml_generate_text_llm_result, '$.Transaction_ID') as int64))
# where 1=1
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ####Inspect the output

# %%
# %%bigquery
# select * except (Day, Month, Year, store_nbr, family, sales_amount, data_source, load_time)
# from retails_stg.Transactions
# where holiday is not null
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    Transaction_ID        date  on_promotion         holiday
# 0               5  2013-01-01         False  New Year's Day
# 1               4  2013-01-01         False  New Year's Day
# 2               6  2013-01-01         False  New Year's Day
# 3               7  2013-01-01         False  New Year's Day
# 4               3  2013-01-01         False  New Year's Day
# 5               2  2013-01-01         False  New Year's Day
# 6               1  2013-01-01         False  New Year's Day
# 7               8  2013-01-01         False  New Year's Day
# 8               9  2013-01-01         False  New Year's Day
# 9               0  2013-01-01         False  New Year's Day

# %% [markdown]
# Apply at a larger scale

# %%
# %%bigquery
# create or replace table retails_stg.Transactions_10k as
#   select *
#   from retails_stg.Transactions
#   where date is not null
#   and on_promotion is not null
#   limit 10000
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select *
# from retails_stg.Transactions_10k
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#       Transaction_ID        date Day Month  Year  store_nbr  \
# 0               1692  2013-01-01  01    01  2013          7
# 1                  9  2013-01-01  01    01  2013          1
# 2                273  2013-01-01  01    01  2013         17
# 3               1263  2013-01-01  01    01  2013         44
# 4               1230  2013-01-01  01    01  2013         43
# ...              ...         ...  ..   ...   ...        ...
# 9995           96226  2013-02-23  23    02  2013          9
# 9996           96721  2013-02-24  24    02  2013         22
# 9997           97117  2013-02-24  24    02  2013         33
# 9998           97810  2013-02-24  24    02  2013         52
# 9999           96490  2013-02-24  24    02  2013         16
#
#                           family  sales_amount  on_promotion data_source  \
# 0                           DELI           0.0         False      kaggle
# 1                           DELI           0.0         False      kaggle
# 2                           DELI           0.0         False      kaggle
# 3                           DELI           0.0         False      kaggle
# 4                           DELI           0.0         False      kaggle
# ...                          ...           ...           ...         ...
# 9995  SCHOOL AND OFFICE SUPPLIES           0.0         False      kaggle
# 9996  SCHOOL AND OFFICE SUPPLIES           0.0         False      kaggle
# 9997  SCHOOL AND OFFICE SUPPLIES           0.0         False      kaggle
# 9998  SCHOOL AND OFFICE SUPPLIES           0.0         False      kaggle
# 9999  SCHOOL AND OFFICE SUPPLIES           0.0         False      kaggle
#
#                             load_time         holiday
# 0    2024-02-10 18:23:57.714487+00:00            None
# 1    2024-02-10 18:23:57.714487+00:00  New Year's Day
# 2    2024-02-10 18:23:57.714487+00:00            None
# 3    2024-02-10 18:23:57.714487+00:00            None
# 4    2024-02-10 18:23:57.714487+00:00            None
# ...                               ...             ...
# 9995 2024-02-10 18:23:57.714487+00:00            None
# 9996 2024-02-10 18:23:57.714487+00:00            None
# 9997 2024-02-10 18:23:57.714487+00:00            None
# 9998 2024-02-10 18:23:57.714487+00:00            None
# 9999 2024-02-10 18:23:57.714487+00:00            None
#
# [10000 rows x 12 columns]

# %%
# %%bigquery
# declare prompt_query STRING default "Suggest a holiday for each transaction. Return the output as json, include the Transaction_ID and holiday in the output";
# create or replace table retails_stg_ai.holiday_predictions_raw_10k as
#   select *
#   from ML.generate_text(
#     model remote_models.gemini_pro,
#     (
#     select concat(prompt_query, to_json_string(json_object("Transaction_ID", Transaction_ID, "date", date,
#                   "on_promotion", on_promotion))) as prompt
#     from retails_stg.Transactions_10k
#     ),
#     struct(0 as temperature, 8192 as max_output_tokens, 0.0 as top_p, 1 as top_k, TRUE as flatten_json_output)
#   );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select creation_time, end_time, query
# from `region-us`.INFORMATION_SCHEMA.JOBS
# where job_id = 'cc8479fa-607b-42ad-b5a9-142dd8b26504'
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                      creation_time                         end_time  \
# 0 2024-04-10 16:59:02.556000+00:00 2024-04-10 17:43:55.764000+00:00
#
#                                                query
# 0  declare prompt_query STRING default "Suggest a...

# %%
# %%bigquery
# create or replace table retails_stg_ai.holiday_predictions_formatted_10k as
#   select trim(replace(replace(replace(ml_generate_text_llm_result, '```json', ''), '```', ''), '\n', '')) as ml_generate_text_llm_result
#   from retails_stg_ai.holiday_predictions_raw_10k;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select count(*) as holiday_count
# from retails_stg_ai.holiday_predictions_formatted_10k
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    holiday_count
# 0          10000

# %%
# %%bigquery
# select *
# from retails_stg_ai.holiday_predictions_formatted_10k
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                             ml_generate_text_llm_result
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 9995  {  "Transaction_ID": 40453,  "date": "2013-01-...
# 9996  {  "Transaction_ID": 40518,  "date": "2013-01-...
# 9997  {  "Transaction_ID": 40895,  "date": "2013-01-...
# 9998  {  "Transaction_ID": 40933,  "date": "2013-01-...
# 9999  {  "Transaction_ID": 40967,  "date": "2013-01-...
#
# [10000 rows x 1 columns]

# %%
# %%bigquery
# update retails_stg.Transactions set holiday =
#   (select json_value(ml_generate_text_llm_result, '$.holiday')
#    from retails_stg_ai.holiday_predictions_formatted_10k
#    where Transaction_ID = cast(json_value(ml_generate_text_llm_result, '$.Transaction_ID') as int64))
# where 1=1
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select count(*) as holiday_count
# from retails_stg.Transactions
# where holiday is not null
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    holiday_count
# 0           9980

# %%
# %%bigquery
# select on_promotion, holiday, count(*) as count
# from retails_stg.Transactions
# where on_promotion is not null
# group by on_promotion, holiday
# order by count(*) desc
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     on_promotion                     holiday    count
# 0          False                        None  2379579
# 1           True                        None   611329
# 2          False              New Year's Day     2883
# 3          False              Presidents Day     1693
# 4          False  Martin Luther King Jr. Day     1461
# 5          False            Chinese New Year      935
# 6          False          Lincoln's Birthday      740
# 7          False               Groundhog Day      657
# 8          False             Valentine's Day      390
# 9          False               Australia Day      378
# 10         False                   Christmas      372
# 11         False       Washington's Birthday      246
# 12         False                Memorial Day      198
# 13         False                    Epiphany       27

# %%
# %%bigquery
# update retails_stg.Transactions
#   set data_source = 'kaggle' where holiday is not null
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Part 4: Merge changes into target table

# %% [markdown]
# ####Mrds table

# %%
# %%bigquery
# create or replace table retails_csp.Mrds_copy as select * from retails_csp.Mrds
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# alter table retails_csp.Mrds
#   add column county_predictions string;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# alter table retails_csp.Mrds
#   add column mineral_type string;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# declare current_ts TIMESTAMP;
# set current_ts = current_timestamp();
#
# create temp table updates as
#   select s.*
#   from retails_csp.Mrds t join retails_stg.Mrds s
#   on t.Dep_ID = s.Dep_ID
#   where s.county_predictions != t.county_predictions
#   or s.mineral_type != t.mineral_type;
#
# update retails_csp.Mrds
# set discontinue_time = timestamp_sub(current_ts, interval 1 second), status_flag = false
# where Dep_ID in (select Dep_ID from updates);
#
# insert into retails_csp.Mrds
#   (Dep_id, url, mrds_id, mas_id, site_name, latitude, longitude, region,
#     country, state, county, com_type, commod1, commod2, commod3, mineral_type, county_predictions, data_source, load_time, effective_time, status_flag)
#     (select Dep_id, url, mrds_id, mas_id, site_name, latitude, longitude, region,
#       country, state, county, com_type, commod1, commod2, commod3, mineral_type, county_predictions, data_source, load_time, current_ts, true
#       from updates);
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select count(*) as num_records
# from retails_csp.Mrds
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    num_records
# 0       304632

# %% [markdown]
# ####Transactions table

# %%
# %%bigquery
# create or replace table retails_csp.Transactions_copy as select * from retails_csp.Transactions
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# alter table retails_csp.Transactions
#   add column holiday string;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# declare current_ts TIMESTAMP;
# set current_ts = current_timestamp();
#
# create temp table updates as
#   select s.*
#   from retails_csp.Transactions t join retails_stg.Transactions s
#   on t.Transaction_ID = s.Transaction_ID
#   where t.status_flag = true
#   and (s.Transaction_ID is not null and t.Transaction_ID is null
#   or s.holiday is not null and t.holiday is null);
#
# update retails_csp.Transactions
# set discontinue_time = timestamp_sub(current_ts, interval 1 second), status_flag = false
# where Transaction_ID in (select Transaction_ID from updates);
#
# insert into retails_csp.Transactions
#   (Transaction_ID, date, Day, Month, Year, store_nbr, family, sales_amount,
#     on_promotion, holiday, data_source, load_time, effective_time, status_flag)
#     (select Transaction_ID, date, Day, Month, Year, store_nbr, family, sales_amount,
#     on_promotion, holiday, data_source, load_time, current_ts, true
#       from updates);
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select count(*) as num_records
# from retails_csp.Transactions
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    num_records
# 0      3000888
